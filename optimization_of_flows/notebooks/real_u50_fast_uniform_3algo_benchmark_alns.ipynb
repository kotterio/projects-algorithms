# %% [markdown]
# # Real U50 Fast Uniform Benchmark: GAP (with ALNS) + MILP + Genetic
#
# Быстрый ноутбук для уменьшенного датасета, где задачи урезаются пространственно-равномерно,
# а агенты урезаются равномерно по депо с запасом по сменному времени.
#
# Основной параметр: `DOWNSCALE_FACTOR` (например, `2..10`).

# %%
from __future__ import annotations

from pathlib import Path
import sys
import json
import importlib
import inspect
import pandas as pd
import alns

def find_repo_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (candidate / "src").exists() and (candidate / "notebooks").exists():
            return candidate
    raise RuntimeError("Repo root not found")


REPO_ROOT = find_repo_root(Path.cwd().resolve())
SRC_DIR = REPO_ROOT / "src"
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

# Clean cached modules to avoid stale code in long-lived kernels.
for mod_name in list(sys.modules):
    if mod_name.startswith("flowopt"):
        sys.modules.pop(mod_name, None)

import flowopt.pipeline as fp
from flowopt.pipelines.u50_fast_dataset import build_fast_u50_dataset

fp = importlib.reload(fp)

run_real_gap_vrp = fp.run_real_gap_vrp
run_real_gap_vrp_alns = fp.run_real_gap_vrp_alns
run_real_gap_vrp_saa = fp.run_real_gap_vrp_saa
run_real_milp = fp.run_real_milp
run_real_genetic = fp.run_real_genetic

milp_sig = inspect.signature(run_real_milp)
if "time_limit_sec" not in milp_sig.parameters:
    raise RuntimeError(f"Stale run_real_milp loaded: signature={milp_sig}")

pd.set_option("display.max_colwidth", 160)
print("REPO_ROOT:", REPO_ROOT)
print("pipeline module:", fp.__file__)
print("run_real_gap_vrp_alns signature:", inspect.signature(run_real_gap_vrp_alns))
# Out:
# REPO_ROOT: C:\Users\Пользователь\Optimization-of-flows-3
# pipeline module: C:\Users\Пользователь\Optimization-of-flows-3\src\flowopt\pipeline.py
# run_real_gap_vrp_alns signature: (*, dataset_path: 'Path | str' = WindowsPath('C:/Users/Пользователь/Optimization-of-flows-3/src/data/real/real_simple/dataset_real_spb_simple.json'), step1_method: 'str' = 'lp', gap_iter: 'int' = 120, use_repair: 'bool' = True, max_agents: 'int | None' = None, alns_iterations: 'int' = 150, alns_removal_q: 'int' = 30, alns_seed: 'int' = 42, alns_log_every: 'int' = 10, start_temperature: 'float' = 1000.0, end_temperature: 'float' = 1.0, temperature_step: 'float' = 0.999, show_progress: 'bool' = False, verbose: 'bool' = False, progress_hook: 'Callable[[str], None] | None' = None) -> 'RunMetrics'

# %%
# Build reduced dataset variant (uniform by depot/space)
BASE_DATASET_PATH = REPO_ROOT / "src" / "data" / "real" / "day_load_profiles" / "u50" / "fast_uniform" / "simplified_a_only" / "dataset_real_spb_day_u50_A_only_simplified.json"
FAST_ROOT = REPO_ROOT / "src" / "data" / "real" / "day_load_profiles" / "u50" / "fast_uniform"
FAST_ROOT.mkdir(parents=True, exist_ok=True)

DOWNSCALE_FACTOR = 10  # try 2..10
SEED = 42
GRID_SIZE = 6
SAFETY_UTILIZATION = 0.85
FORCE_REBUILD = False

factor_tag = f"f{int(DOWNSCALE_FACTOR) if float(DOWNSCALE_FACTOR).is_integer() else str(DOWNSCALE_FACTOR).replace('.', '_')}"
DATASET_PATH = FAST_ROOT / f"dataset_real_spb_day_u50_fast_{factor_tag}.json"
SUMMARY_PATH = FAST_ROOT / f"summary_real_spb_day_u50_fast_{factor_tag}.json"

if FORCE_REBUILD or not DATASET_PATH.exists() or not SUMMARY_PATH.exists():
    summary = build_fast_u50_dataset(
        base_dataset_path=BASE_DATASET_PATH,
        out_dataset_path=DATASET_PATH,
        downscale_factor=float(DOWNSCALE_FACTOR),
        seed=SEED,
        grid_size=GRID_SIZE,
        safety_utilization=SAFETY_UTILIZATION,
    )
else:
    summary = json.loads(SUMMARY_PATH.read_text(encoding="utf-8"))

print("BASE_DATASET_PATH:", BASE_DATASET_PATH)
print("DATASET_PATH     :", DATASET_PATH)
print("SUMMARY_PATH     :", SUMMARY_PATH)
print("before ->", summary["before"])
print("after  ->", summary["after"])

pd.DataFrame(
    {
        "depot_id": list(summary["selected_tasks_by_depot"].keys()),
        "tasks_selected": list(summary["selected_tasks_by_depot"].values()),
        "agents_selected": [summary["selected_agents_by_depot"][d] for d in summary["selected_tasks_by_depot"].keys()],
        "required_agents_time_model": [summary["required_agents_by_depot"][d] for d in summary["selected_tasks_by_depot"].keys()],
        "required_hours_time_model": [summary["required_hours_by_depot"][d] for d in summary["selected_tasks_by_depot"].keys()],
    }
).sort_values("tasks_selected", ascending=False)
# Out:
# BASE_DATASET_PATH: C:\Users\Пользователь\Optimization-of-flows-3\src\data\real\day_load_profiles\u50\fast_uniform\simplified_a_only\dataset_real_spb_day_u50_A_only_simplified.json
# DATASET_PATH     : C:\Users\Пользователь\Optimization-of-flows-3\src\data\real\day_load_profiles\u50\fast_uniform\dataset_real_spb_day_u50_fast_f10.json
# SUMMARY_PATH     : C:\Users\Пользователь\Optimization-of-flows-3\src\data\real\day_load_profiles\u50\fast_uniform\summary_real_spb_day_u50_fast_f10.json
# before -> {'agents': 432, 'tasks': 301, 'mno_nodes': 265}
# after  -> {'agents': 50, 'tasks': 32, 'mno_nodes': 32, 'task_sources': 32}
#      depot_id  tasks_selected  agents_selected  required_agents_time_model  \
# 0  1533456031              15                9                           9
# 3      230361              10               17                           5
# 2  1903257537               6                6                           3
# 1  1746883131               1               18                           1
#
#    required_hours_time_model
# 0                 105.742239
# 3                  51.709893
# 2                  33.583799
# 1                   6.696456

# %%
# Dataset inspection + optional profile patching
import flowopt.core as core
import flowopt.genetic_solver_components as ga

with DATASET_PATH.open("r", encoding="utf-8") as f:
    dataset = json.load(f)

meta = dataset.get("metadata", {})
counts = {
    "nodes": len(dataset.get("graph", {}).get("nodes", [])),
    "edges": len(dataset.get("graph", {}).get("edges", [])),
    "agents": len(dataset.get("agents", [])),
    "tasks": len(dataset.get("tasks", [])),
    "objects": len({t.get("destination_node_id") for t in dataset.get("tasks", [])}),
    "sources": len({t.get("source_node_id") for t in dataset.get("tasks", [])}),
}

print("dataset name:", meta.get("name"))
print("counts:", counts)
print("fast_profile:", meta.get("fast_profile", {}))

APPLY_PROFILE_LIMITS = True
if APPLY_PROFILE_LIMITS:
    profiles = meta.get("vehicle_profiles", {})
    for vt, p in profiles.items():
        km = float(p.get("max_daily_km", core.MAX_DAILY_KM_BY_TYPE.get(vt, 130.0)))
        hh = float(p.get("max_shift_hours", core.MAX_SHIFT_HOURS_BY_TYPE.get(vt, 10.0)))
        sp = float(p.get("avg_speed_kmph", core.AVG_SPEED_KMPH_BY_TYPE.get(vt, 24.0)))
        core.MAX_DAILY_KM_BY_TYPE[vt] = km
        core.MAX_SHIFT_HOURS_BY_TYPE[vt] = hh
        core.AVG_SPEED_KMPH_BY_TYPE[vt] = sp
        ga.MAX_DAILY_KM_BY_TYPE[vt] = km
        ga.MAX_SHIFT_HOURS_BY_TYPE[vt] = hh
        ga.AVG_SPEED_KMPH_BY_TYPE[vt] = sp

    print("Patched limits from vehicle_profiles for:", sorted(profiles.keys()))

pd.DataFrame([counts])
# Out:
# dataset name: real_spb_u50_fast_f10
# counts: {'nodes': 46730, 'edges': 127100, 'agents': 50, 'tasks': 32, 'objects': 5, 'sources': 32}
# fast_profile: {'source_dataset': 'C:\\Users\\Пользователь\\Optimization-of-flows-3\\src\\data\\real\\day_load_profiles\\u50\\simplified_a_only\\dataset_real_spb_day_u50_A_only_simplified.json', 'downscale_factor': 10.0, 'seed': 42, 'grid_size': 6, 'safety_utilization': 0.85, 'selected_tasks': 32, 'selected_agents': 50, 'demoted_mno_to_road': 233, 'required_agents_by_depot': {'1533456031': 9, '1746883131': 1, '1903257537': 3, '230361': 5}, 'selected_agents_by_depot': {'1533456031': 9, '1746883131': 18, '1903257537': 6, '230361': 17}, 'selected_tasks_by_depot': {'1533456031': 15, '1746883131': 1, '1903257537': 6, '230361': 10}, 'required_hours_by_depot': {'1533456031': 105.742239, '1746883131': 6.696456, '1903257537': 33.583799, '230361': 51.709893}}
# Patched limits from vehicle_profiles for: ['VT_A', 'VT_AB', 'VT_ABD', 'VT_AD', 'VT_C', 'VT_CD']
#    nodes   edges  agents  tasks  objects  sources
# 0  46730  127100      50     32        5       32

# %%
# Fast run of 5 algorithms
from time import perf_counter
from datetime import datetime
# GAP
GAP_STEP1_METHOD = "dataset"
GAP_ITER = 20
MAX_AGENTS = None
USE_REPAIR = True
# GAP + ALNS
ALNS_ITERATIONS = 20
ALNS_REMOVAL_Q = 5
ALNS_RANDOM_SEED = 42
ALNS_START_TEMP = 80
ALNS_END_TEMP = 1
ALNS_STEP = 0.98
# MILP
RMILP_TIME_LIMIT_SEC = 90
RMILP_UNASSIGNED_PENALTY = 1e7
# Genetic (kept moderate for speed)
GA_POPULATION_SIZE = 20
GA_GENERATIONS = 20
GA_ELITE_SIZE = 3
GA_SEED = 42
GA_GENERATION_SCALE = 1.0
GA_MIN_GENERATIONS = 10
# GAP + SAA
SAA_SAMPLE_SIZE = 12
SAA_ITERATIONS = 60
SAA_ROUTE_MAX_SIZE = 8
SAA_SEED = 42
SAA_LOG_EVERY = 10
SHOW_ALGO_PROGRESS = True
SHOW_SOLVER_DETAILS = False
REQUIRE_FULL_ASSIGNMENT = False
def make_progress_logger(enabled: bool):
    if not enabled:
        return None
    t0 = perf_counter()
    def _log(message: str) -> None:
        dt = perf_counter() - t0
        print(f"[+{dt:7.1f}s] {message}", flush=True)
    return _log
progress_log = make_progress_logger(SHOW_ALGO_PROGRESS)
def run_with_live_status(label, fn, **kwargs):
    if progress_log is not None:
        progress_log(f"{label}: START")
    ts = perf_counter()
    out = fn(**kwargs)
    if progress_log is not None:
        progress_log(f"{label}: DONE in {perf_counter() - ts:.1f}s")
    return out
results = [
    run_with_live_status(
        "GAP-VRP",
        run_real_gap_vrp,
        dataset_path=DATASET_PATH,
        step1_method=GAP_STEP1_METHOD,
        gap_iter=GAP_ITER,
        max_agents=MAX_AGENTS,
        use_repair=USE_REPAIR,
        show_progress=SHOW_SOLVER_DETAILS,
        verbose=False,
        progress_hook=progress_log,
    ),
    run_with_live_status(
        "GAP-VRP-ALNS",
        run_real_gap_vrp_alns,
        dataset_path=DATASET_PATH,
        step1_method=GAP_STEP1_METHOD,
        gap_iter=GAP_ITER,
        max_agents=MAX_AGENTS,
        use_repair=USE_REPAIR,
        alns_iterations=ALNS_ITERATIONS,
        alns_removal_q=ALNS_REMOVAL_Q,
        alns_seed=ALNS_RANDOM_SEED,
        start_temperature=ALNS_START_TEMP,
        end_temperature=ALNS_END_TEMP,
        temperature_step=ALNS_STEP,
        show_progress=SHOW_SOLVER_DETAILS,
        verbose=False,
        progress_hook=progress_log,
    ),
    run_with_live_status(
        "REAL-MILP",
        run_real_milp,
        dataset_path=DATASET_PATH,
        time_limit_sec=RMILP_TIME_LIMIT_SEC,
        unassigned_penalty=RMILP_UNASSIGNED_PENALTY,
        show_progress=SHOW_SOLVER_DETAILS,
        progress_hook=progress_log,
    ),
    run_with_live_status(
        "REAL-GENETIC",
        run_real_genetic,
        dataset_path=DATASET_PATH,
        population_size=GA_POPULATION_SIZE,
        generations=GA_GENERATIONS,
        elite_size=GA_ELITE_SIZE,
        seed=GA_SEED,
        generation_scale=GA_GENERATION_SCALE,
        min_generations=GA_MIN_GENERATIONS,
        show_progress=SHOW_SOLVER_DETAILS,
        progress_hook=progress_log,
    ),
    run_with_live_status(
    "GAP-VRP-SAA",
    run_real_gap_vrp_saa,
    dataset_path=DATASET_PATH,
    step1_method=GAP_STEP1_METHOD,
    gap_iter=GAP_ITER,
    max_agents=MAX_AGENTS,
    use_repair=USE_REPAIR,
    saa_sample_size=SAA_SAMPLE_SIZE,
    saa_iterations=SAA_ITERATIONS,
    saa_route_max_size=SAA_ROUTE_MAX_SIZE,
    saa_seed=SAA_SEED,
    saa_log_every=SAA_LOG_EVERY,
    show_progress=SHOW_SOLVER_DETAILS,
    verbose=False,
    progress_hook=progress_log,
    ),
]
benchmark_df = pd.DataFrame([r.as_dict() for r in results])
benchmark_df = benchmark_df.sort_values(
    by=["all_checks_ok", "transport_work_ton_km", "total_km", "runtime_sec"],
    ascending=[False, True, True, True],
    na_position="last",
).reset_index(drop=True)
# Save benchmark artifact
LOCAL_OUT_DIR = REPO_ROOT / "notebooks" / "local" / "real_data" / "u50_fast_uniform" / factor_tag
LOCAL_OUT_DIR.mkdir(parents=True, exist_ok=True)
RUN_TAG = datetime.now().strftime("%Y%m%d_%H%M%S")
RESULT_JSON_PATH = LOCAL_OUT_DIR / f"benchmark_u50_fast_alns_{factor_tag}_{RUN_TAG}.json"
records = benchmark_df.where(pd.notna(benchmark_df), None).to_dict(orient="records")
artifact = {
    "created_at": datetime.now().isoformat(timespec="seconds"),
    "notebook": "real_u50_fast_uniform_3algo_benchmark_alns.ipynb",
    "dataset_path": str(DATASET_PATH),
    "config": {
        "downscale_factor": DOWNSCALE_FACTOR,
        "seed": SEED,
        "grid_size": GRID_SIZE,
        "safety_utilization": SAFETY_UTILIZATION,
        "gap_step1_method": GAP_STEP1_METHOD,
        "gap_iter": GAP_ITER,
        "max_agents": MAX_AGENTS,
        "use_repair": USE_REPAIR,
        "alns_iterations": ALNS_ITERATIONS,
        "alns_removal_q": ALNS_REMOVAL_Q,
        "alns_seed": ALNS_RANDOM_SEED,
        "alns_start_temp": ALNS_START_TEMP,
        "alns_end_temp": ALNS_END_TEMP,
        "alns_step": ALNS_STEP,
        "saa_sample_size": SAA_SAMPLE_SIZE,
        "saa_iterations": SAA_ITERATIONS,
        "saa_route_max_size": SAA_ROUTE_MAX_SIZE,
        "saa_seed": SAA_SEED,
        "saa_log_every": SAA_LOG_EVERY,
        "rmilp_time_limit_sec": RMILP_TIME_LIMIT_SEC,
        "rmilp_unassigned_penalty": RMILP_UNASSIGNED_PENALTY,
        "ga_population_size": GA_POPULATION_SIZE,
        "ga_generations": GA_GENERATIONS,
        "ga_elite_size": GA_ELITE_SIZE,
        "ga_seed": GA_SEED,
        "ga_generation_scale": GA_GENERATION_SCALE,
        "ga_min_generations": GA_MIN_GENERATIONS,
    },
    "results": records,
}
RESULT_JSON_PATH.write_text(json.dumps(artifact, ensure_ascii=False, indent=2), encoding="utf-8")
print("Saved:", RESULT_JSON_PATH)
if REQUIRE_FULL_ASSIGNMENT:
    if (benchmark_df["unassigned_tasks"].fillna(10**9) > 0).any():
        raise AssertionError("Some algorithms still have unassigned tasks")
main_cols = [
    "algorithm",
    "feasible",
    "all_checks_ok",
    "assigned_routes",
    "unassigned_tasks",
    "active_agents",
    "transport_work_ton_km",
    "total_km",
    "deadhead_km",
    "deadhead_share_pct",
    "total_hours",
    "runtime_sec",
    "alns_gain",
    "solver_error",
]
benchmark_df[[c for c in main_cols if c in benchmark_df.columns]]
# Out:
# [+    0.0s] GAP-VRP: START
# [+    0.0s] [real_gap_vrp] load dataset: C:\Users\Пользователь\Optimization-of-flows-3\src\data\real\day_load_profiles\u50\fast_uniform\dataset_real_spb_day_u50_fast_f10.json
# [+    1.5s] [real_gap_vrp] dataset loaded (nodes=46730, edges=127100, agents=50, tasks=32)
# [+    1.5s] [real_gap_vrp] build nx graph
# [+    2.2s] [real_gap_vrp] solver start
# [+    2.2s] [real_gap_vrp] [GAP-VRP] start: GAP-Lagrangean + VRP(NN+2opt) [step1=lp]
# [+    2.2s] [real_gap_vrp] [GAP-VRP] step1: task generation
# [+    2.2s] [real_gap_vrp] [GAP-step1] LP setup: sources=32, sinks=9, variables=288, total_waste_tons=37.617
# [+    2.7s] [real_gap_vrp] [GAP-step1] distance matrix: sources=1/32, elapsed=0.5s
# [+    3.3s] [real_gap_vrp] [GAP-step1] distance matrix: sources=2/32, elapsed=1.1s
# [+    3.7s] [real_gap_vrp] [GAP-step1] distance matrix: sources=3/32, elapsed=1.5s
# [+    4.2s] [real_gap_vrp] [GAP-step1] distance matrix: sources=4/32, elapsed=2.0s
# [+    4.7s] [real_gap_vrp] [GAP-step1] distance matrix: sources=5/32, elapsed=2.6s
# [+    5.9s] [real_gap_vrp] [GAP-step1] distance matrix: sources=6/32, elapsed=3.7s
# [+    6.6s] [real_gap_vrp] [GAP-step1] distance matrix: sources=7/32, elapsed=4.5s
# [+    7.7s] [real_gap_vrp] [GAP-step1] distance matrix: sources=8/32, elapsed=5.5s
# [+    8.7s] [real_gap_vrp] [GAP-step1] distance matrix: sources=9/32, elapsed=6.6s
# [+    9.6s] [real_gap_vrp] [GAP-step1] distance matrix: sources=10/32, elapsed=7.4s
# [+   10.9s] [real_gap_vrp] [GAP-step1] distance matrix: sources=11/32, elapsed=8.7s
# [+   11.7s] [real_gap_vrp] [GAP-step1] distance matrix: sources=12/32, elapsed=9.6s
# [+   12.8s] [real_gap_vrp] [GAP-step1] distance matrix: sources=13/32, elapsed=10.7s
# [+   13.8s] [real_gap_vrp] [GAP-step1] distance matrix: sources=14/32, elapsed=11.7s
# [+   14.6s] [real_gap_vrp] [GAP-step1] distance matrix: sources=15/32, elapsed=12.5s
# [+   15.6s] [real_gap_vrp] [GAP-step1] distance matrix: sources=16/32, elapsed=13.4s
# [+   16.4s] [real_gap_vrp] [GAP-step1] distance matrix: sources=17/32, elapsed=14.2s
# [+   16.9s] [real_gap_vrp] [GAP-step1] distance matrix: sources=18/32, elapsed=14.7s
# [+   17.4s] [real_gap_vrp] [GAP-step1] distance matrix: sources=19/32, elapsed=15.2s
# [+   18.0s] [real_gap_vrp] [GAP-step1] distance matrix: sources=20/32, elapsed=15.8s
# [+   18.5s] [real_gap_vrp] [GAP-step1] distance matrix: sources=21/32, elapsed=16.3s
# [+   19.3s] [real_gap_vrp] [GAP-step1] distance matrix: sources=22/32, elapsed=17.1s
# [+   19.8s] [real_gap_vrp] [GAP-step1] distance matrix: sources=23/32, elapsed=17.6s
# [+   20.4s] [real_gap_vrp] [GAP-step1] distance matrix: sources=24/32, elapsed=18.2s
# [+   20.8s] [real_gap_vrp] [GAP-step1] distance matrix: sources=25/32, elapsed=18.6s
# [+   21.7s] [real_gap_vrp] [GAP-step1] distance matrix: sources=26/32, elapsed=19.5s
# [+   22.3s] [real_gap_vrp] [GAP-step1] distance matrix: sources=27/32, elapsed=20.2s
# [+   23.0s] [real_gap_vrp] [GAP-step1] distance matrix: sources=28/32, elapsed=20.8s
# [+   23.6s] [real_gap_vrp] [GAP-step1] distance matrix: sources=29/32, elapsed=21.4s
# [+   24.6s] [real_gap_vrp] [GAP-step1] distance matrix: sources=30/32, elapsed=22.4s
# [+   25.2s] [real_gap_vrp] [GAP-step1] distance matrix: sources=31/32, elapsed=23.1s
# [+   26.4s] [real_gap_vrp] [GAP-step1] distance matrix: sources=32/32, elapsed=24.3s
# [+   26.4s] [real_gap_vrp] [GAP-step1] distance matrix built in 24.3s
# [+   26.4s] [real_gap_vrp] [GAP-step1] LP eq constraints built: 32 rows in 0.0s
# [+   26.4s] [real_gap_vrp] [GAP-step1] LP ub constraints built: 9 rows in 0.0s
# [+   26.4s] [real_gap_vrp] [GAP-step1] linprog start: method=highs
# [+   26.5s] [real_gap_vrp] [GAP-step1] linprog done in 0.0s: success=True, status=0
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=1/32, tasks=1, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=2/32, tasks=2, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=3/32, tasks=3, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=4/32, tasks=4, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=5/32, tasks=5, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=6/32, tasks=6, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=7/32, tasks=7, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=8/32, tasks=8, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=9/32, tasks=9, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=10/32, tasks=10, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=11/32, tasks=11, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=12/32, tasks=12, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=13/32, tasks=13, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=14/32, tasks=14, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=15/32, tasks=15, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=16/32, tasks=16, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=17/32, tasks=17, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=18/32, tasks=18, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=19/32, tasks=19, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=20/32, tasks=20, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=21/32, tasks=21, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=22/32, tasks=22, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=23/32, tasks=23, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=24/32, tasks=24, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=25/32, tasks=25, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=26/32, tasks=26, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=27/32, tasks=27, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=28/32, tasks=28, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=29/32, tasks=29, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=30/32, tasks=30, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=31/32, tasks=31, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] build tasks: sources=32/32, tasks=32, elapsed=0.0s
# [+   26.5s] [real_gap_vrp] [GAP-step1] step1 LP tasks built: tasks=32, elapsed=0.1s
# [+   26.5s] [real_gap_vrp] [GAP-VRP] step1 done in 24.3s, tasks=32
# [+   26.5s] [real_gap_vrp] [GAP-VRP] step2: GAP Lagrangean, iter=20
# [+   26.5s] [real_gap_vrp] [GAP-LR] prepare matrices: agents=50, tasks=32, max_iter=20
# [+   28.0s] [real_gap_vrp] [GAP-LR] precompute costs: 5/50 agents
# [+   30.1s] [real_gap_vrp] [GAP-LR] precompute costs: 10/50 agents
# [+   30.4s] [real_gap_vrp] [GAP-LR] precompute costs: 15/50 agents
# [+   30.4s] [real_gap_vrp] [GAP-LR] precompute costs: 20/50 agents
# [+   30.4s] [real_gap_vrp] [GAP-LR] precompute costs: 25/50 agents
# [+   31.7s] [real_gap_vrp] [GAP-LR] precompute costs: 30/50 agents
# [+   33.9s] [real_gap_vrp] [GAP-LR] precompute costs: 35/50 agents
# [+   33.9s] [real_gap_vrp] [GAP-LR] precompute costs: 40/50 agents
# [+   33.9s] [real_gap_vrp] [GAP-LR] precompute costs: 45/50 agents
# [+   33.9s] [real_gap_vrp] [GAP-LR] precompute costs: 50/50 agents
# [+   33.9s] [real_gap_vrp] [GAP-LR] precompute done
# [+   34.0s] [real_gap_vrp] [GAP-LR] iter 1/20 started
# [+   34.3s] [real_gap_vrp] [GAP-LR] iter 1/20, agent 5/50, id=AGENT_00277, free_tasks=32
# [+   34.6s] [real_gap_vrp] [GAP-LR] iter 1/20, agent 10/50, id=AGENT_00516, free_tasks=31
# [+   34.9s] [real_gap_vrp] [GAP-LR] iter 1/20, agent 15/50, id=AGENT_00443, free_tasks=32
# [+   35.2s] [real_gap_vrp] [GAP-LR] iter 1/20, agent 20/50, id=AGENT_00392, free_tasks=31
# [+   35.4s] [real_gap_vrp] [GAP-LR] iter 1/20, agent 25/50, id=AGENT_00433, free_tasks=32
# [+   35.6s] [real_gap_vrp] [GAP-LR] iter 1/20, agent 30/50, id=AGENT_00344, free_tasks=32
# [+   36.0s] [real_gap_vrp] [GAP-LR] iter 1/20, agent 35/50, id=AGENT_00118, free_tasks=32
# [+   36.2s] [real_gap_vrp] [GAP-LR] iter 1/20, agent 40/50, id=AGENT_00117, free_tasks=32
# [+   36.5s] [real_gap_vrp] [GAP-LR] iter 1/20, agent 45/50, id=AGENT_00083, free_tasks=32
# [+   36.8s] [real_gap_vrp] [GAP-LR] iter 1/20, agent 50/50, id=AGENT_00030, free_tasks=32
# [+   36.8s] [real_gap_vrp] [GAP-LR] iter 1/20 done: LB=1302.80, UB=inf, assigned=0/32, iter_sec=2.9
# [+   36.8s] [real_gap_vrp] [GAP-LR] iter 2/20 started
# [+   37.2s] [real_gap_vrp] [GAP-LR] iter 2/20, agent 5/50, id=AGENT_00277, free_tasks=32
# [+   37.5s] [real_gap_vrp] [GAP-LR] iter 2/20, agent 10/50, id=AGENT_00516, free_tasks=31
# [+   37.8s] [real_gap_vrp] [GAP-LR] iter 2/20, agent 15/50, id=AGENT_00443, free_tasks=32
# [+   38.0s] [real_gap_vrp] [GAP-LR] iter 2/20, agent 20/50, id=AGENT_00392, free_tasks=31
# [+   38.3s] [real_gap_vrp] [GAP-LR] iter 2/20, agent 25/50, id=AGENT_00433, free_tasks=32
# [+   38.6s] [real_gap_vrp] [GAP-LR] iter 2/20, agent 30/50, id=AGENT_00344, free_tasks=32
# [+   38.9s] [real_gap_vrp] [GAP-LR] iter 2/20, agent 35/50, id=AGENT_00118, free_tasks=32
# [+   39.3s] [real_gap_vrp] [GAP-LR] iter 2/20, agent 40/50, id=AGENT_00117, free_tasks=32
# [+   39.6s] [real_gap_vrp] [GAP-LR] iter 2/20, agent 45/50, id=AGENT_00083, free_tasks=32
# [+   39.9s] [real_gap_vrp] [GAP-LR] iter 2/20, agent 50/50, id=AGENT_00030, free_tasks=32
# [+   39.9s] [real_gap_vrp] [GAP-LR] iter 2/20 done: LB=-2058.57, UB=inf, assigned=0/32, iter_sec=3.1
# [+   42.9s] [real_gap_vrp] [GAP-LR] iter 4/20 started
# [+   43.3s] [real_gap_vrp] [GAP-LR] iter 4/20, agent 5/50, id=AGENT_00277, free_tasks=32
# [+   43.6s] [real_gap_vrp] [GAP-LR] iter 4/20, agent 10/50, id=AGENT_00516, free_tasks=31
# [+   43.9s] [real_gap_vrp] [GAP-LR] iter 4/20, agent 15/50, id=AGENT_00443, free_tasks=32
# [+   44.3s] [real_gap_vrp] [GAP-LR] iter 4/20, agent 20/50, id=AGENT_00392, free_tasks=31
# [+   44.5s] [real_gap_vrp] [GAP-LR] iter 4/20, agent 25/50, id=AGENT_00433, free_tasks=32
# [+   44.8s] [real_gap_vrp] [GAP-LR] iter 4/20, agent 30/50, id=AGENT_00344, free_tasks=32
# [+   45.1s] [real_gap_vrp] [GAP-LR] iter 4/20, agent 35/50, id=AGENT_00118, free_tasks=32
# [+   45.4s] [real_gap_vrp] [GAP-LR] iter 4/20, agent 40/50, id=AGENT_00117, free_tasks=32
# [+   45.7s] [real_gap_vrp] [GAP-LR] iter 4/20, agent 45/50, id=AGENT_00083, free_tasks=32
# [+   46.0s] [real_gap_vrp] [GAP-LR] iter 4/20, agent 50/50, id=AGENT_00030, free_tasks=32
# [+   46.0s] [real_gap_vrp] [GAP-LR] iter 4/20 done: LB=-2058.57, UB=inf, assigned=0/32, iter_sec=3.1
# [+   49.1s] [real_gap_vrp] [GAP-LR] iter 6/20 started
# [+   49.4s] [real_gap_vrp] [GAP-LR] iter 6/20, agent 5/50, id=AGENT_00277, free_tasks=32
# [+   49.7s] [real_gap_vrp] [GAP-LR] iter 6/20, agent 10/50, id=AGENT_00516, free_tasks=31
# [+   50.0s] [real_gap_vrp] [GAP-LR] iter 6/20, agent 15/50, id=AGENT_00443, free_tasks=32
# [+   50.2s] [real_gap_vrp] [GAP-LR] iter 6/20, agent 20/50, id=AGENT_00392, free_tasks=31
# [+   50.4s] [real_gap_vrp] [GAP-LR] iter 6/20, agent 25/50, id=AGENT_00433, free_tasks=32
# [+   50.7s] [real_gap_vrp] [GAP-LR] iter 6/20, agent 30/50, id=AGENT_00344, free_tasks=32
# [+   51.0s] [real_gap_vrp] [GAP-LR] iter 6/20, agent 35/50, id=AGENT_00118, free_tasks=32
# [+   51.3s] [real_gap_vrp] [GAP-LR] iter 6/20, agent 40/50, id=AGENT_00117, free_tasks=32
# [+   51.6s] [real_gap_vrp] [GAP-LR] iter 6/20, agent 45/50, id=AGENT_00083, free_tasks=32
# [+   51.9s] [real_gap_vrp] [GAP-LR] iter 6/20, agent 50/50, id=AGENT_00030, free_tasks=32
# [+   51.9s] [real_gap_vrp] [GAP-LR] iter 6/20 done: LB=-2058.57, UB=inf, assigned=0/32, iter_sec=2.8
# [+   55.1s] [real_gap_vrp] [GAP-LR] iter 8/20 started
# [+   55.4s] [real_gap_vrp] [GAP-LR] iter 8/20, agent 5/50, id=AGENT_00277, free_tasks=32
# [+   55.7s] [real_gap_vrp] [GAP-LR] iter 8/20, agent 10/50, id=AGENT_00516, free_tasks=31
# [+   56.0s] [real_gap_vrp] [GAP-LR] iter 8/20, agent 15/50, id=AGENT_00443, free_tasks=32
# [+   56.2s] [real_gap_vrp] [GAP-LR] iter 8/20, agent 20/50, id=AGENT_00392, free_tasks=31
# [+   56.5s] [real_gap_vrp] [GAP-LR] iter 8/20, agent 25/50, id=AGENT_00433, free_tasks=32
# [+   56.7s] [real_gap_vrp] [GAP-LR] iter 8/20, agent 30/50, id=AGENT_00344, free_tasks=32
# [+   57.1s] [real_gap_vrp] [GAP-LR] iter 8/20, agent 35/50, id=AGENT_00118, free_tasks=32
# [+   57.4s] [real_gap_vrp] [GAP-LR] iter 8/20, agent 40/50, id=AGENT_00117, free_tasks=32
# [+   57.7s] [real_gap_vrp] [GAP-LR] iter 8/20, agent 45/50, id=AGENT_00083, free_tasks=32
# [+   58.0s] [real_gap_vrp] [GAP-LR] iter 8/20, agent 50/50, id=AGENT_00030, free_tasks=32
# [+   58.0s] [real_gap_vrp] [GAP-LR] iter 8/20 done: LB=-2058.57, UB=inf, assigned=0/32, iter_sec=2.9
# [+   61.0s] [real_gap_vrp] [GAP-LR] iter 10/20 started
# [+   61.3s] [real_gap_vrp] [GAP-LR] iter 10/20, agent 5/50, id=AGENT_00277, free_tasks=32
# [+   61.6s] [real_gap_vrp] [GAP-LR] iter 10/20, agent 10/50, id=AGENT_00516, free_tasks=31
# [+   61.9s] [real_gap_vrp] [GAP-LR] iter 10/20, agent 15/50, id=AGENT_00443, free_tasks=32
# [+   62.2s] [real_gap_vrp] [GAP-LR] iter 10/20, agent 20/50, id=AGENT_00392, free_tasks=31
# [+   62.5s] [real_gap_vrp] [GAP-LR] iter 10/20, agent 25/50, id=AGENT_00433, free_tasks=32
# [+   62.7s] [real_gap_vrp] [GAP-LR] iter 10/20, agent 30/50, id=AGENT_00344, free_tasks=32
# [+   63.0s] [real_gap_vrp] [GAP-LR] iter 10/20, agent 35/50, id=AGENT_00118, free_tasks=32
# [+   63.3s] [real_gap_vrp] [GAP-LR] iter 10/20, agent 40/50, id=AGENT_00117, free_tasks=32
# [+   63.6s] [real_gap_vrp] [GAP-LR] iter 10/20, agent 45/50, id=AGENT_00083, free_tasks=32
# [+   63.9s] [real_gap_vrp] [GAP-LR] iter 10/20, agent 50/50, id=AGENT_00030, free_tasks=32
# [+   63.9s] [real_gap_vrp] [GAP-LR] iter 10/20 done: LB=-2058.57, UB=inf, assigned=0/32, iter_sec=2.9
# [+   66.9s] [real_gap_vrp] [GAP-LR] iter 12/20 started
# [+   67.3s] [real_gap_vrp] [GAP-LR] iter 12/20, agent 5/50, id=AGENT_00277, free_tasks=32
# [+   67.6s] [real_gap_vrp] [GAP-LR] iter 12/20, agent 10/50, id=AGENT_00516, free_tasks=31
# [+   67.8s] [real_gap_vrp] [GAP-LR] iter 12/20, agent 15/50, id=AGENT_00443, free_tasks=32
# [+   68.1s] [real_gap_vrp] [GAP-LR] iter 12/20, agent 20/50, id=AGENT_00392, free_tasks=31
# [+   68.3s] [real_gap_vrp] [GAP-LR] iter 12/20, agent 25/50, id=AGENT_00433, free_tasks=32
# [+   68.6s] [real_gap_vrp] [GAP-LR] iter 12/20, agent 30/50, id=AGENT_00344, free_tasks=32
# [+   68.9s] [real_gap_vrp] [GAP-LR] iter 12/20, agent 35/50, id=AGENT_00118, free_tasks=32
# [+   69.2s] [real_gap_vrp] [GAP-LR] iter 12/20, agent 40/50, id=AGENT_00117, free_tasks=32
# [+   69.5s] [real_gap_vrp] [GAP-LR] iter 12/20, agent 45/50, id=AGENT_00083, free_tasks=32
# [+   69.8s] [real_gap_vrp] [GAP-LR] iter 12/20, agent 50/50, id=AGENT_00030, free_tasks=32
# [+   69.8s] [real_gap_vrp] [GAP-LR] iter 12/20 done: LB=-2058.57, UB=inf, assigned=0/32, iter_sec=2.9
# [+   72.8s] [real_gap_vrp] [GAP-LR] iter 14/20 started
# [+   73.2s] [real_gap_vrp] [GAP-LR] iter 14/20, agent 5/50, id=AGENT_00277, free_tasks=32
# [+   73.5s] [real_gap_vrp] [GAP-LR] iter 14/20, agent 10/50, id=AGENT_00516, free_tasks=31
# [+   73.7s] [real_gap_vrp] [GAP-LR] iter 14/20, agent 15/50, id=AGENT_00443, free_tasks=32
# [+   73.9s] [real_gap_vrp] [GAP-LR] iter 14/20, agent 20/50, id=AGENT_00392, free_tasks=31
# [+   74.2s] [real_gap_vrp] [GAP-LR] iter 14/20, agent 25/50, id=AGENT_00433, free_tasks=32
# [+   74.5s] [real_gap_vrp] [GAP-LR] iter 14/20, agent 30/50, id=AGENT_00344, free_tasks=32
# [+   74.8s] [real_gap_vrp] [GAP-LR] iter 14/20, agent 35/50, id=AGENT_00118, free_tasks=32
# [+   75.1s] [real_gap_vrp] [GAP-LR] iter 14/20, agent 40/50, id=AGENT_00117, free_tasks=32
# [+   75.4s] [real_gap_vrp] [GAP-LR] iter 14/20, agent 45/50, id=AGENT_00083, free_tasks=32
# [+   75.7s] [real_gap_vrp] [GAP-LR] iter 14/20, agent 50/50, id=AGENT_00030, free_tasks=32
# [+   75.7s] [real_gap_vrp] [GAP-LR] iter 14/20 done: LB=-2058.57, UB=inf, assigned=0/32, iter_sec=2.9
# [+   78.5s] [real_gap_vrp] [GAP-LR] iter 16/20 started
# [+   78.8s] [real_gap_vrp] [GAP-LR] iter 16/20, agent 5/50, id=AGENT_00277, free_tasks=32
# [+   79.1s] [real_gap_vrp] [GAP-LR] iter 16/20, agent 10/50, id=AGENT_00516, free_tasks=31
# [+   79.4s] [real_gap_vrp] [GAP-LR] iter 16/20, agent 15/50, id=AGENT_00443, free_tasks=32
# [+   79.6s] [real_gap_vrp] [GAP-LR] iter 16/20, agent 20/50, id=AGENT_00392, free_tasks=31
# [+   79.9s] [real_gap_vrp] [GAP-LR] iter 16/20, agent 25/50, id=AGENT_00433, free_tasks=32
# [+   80.2s] [real_gap_vrp] [GAP-LR] iter 16/20, agent 30/50, id=AGENT_00344, free_tasks=32
# [+   80.5s] [real_gap_vrp] [GAP-LR] iter 16/20, agent 35/50, id=AGENT_00118, free_tasks=32
# [+   80.8s] [real_gap_vrp] [GAP-LR] iter 16/20, agent 40/50, id=AGENT_00117, free_tasks=32
# [+   81.1s] [real_gap_vrp] [GAP-LR] iter 16/20, agent 45/50, id=AGENT_00083, free_tasks=32
# [+   81.5s] [real_gap_vrp] [GAP-LR] iter 16/20, agent 50/50, id=AGENT_00030, free_tasks=32
# [+   81.5s] [real_gap_vrp] [GAP-LR] iter 16/20 done: LB=-2058.57, UB=inf, assigned=0/32, iter_sec=2.9
# [+   84.3s] [real_gap_vrp] [GAP-LR] iter 18/20 started
# [+   84.7s] [real_gap_vrp] [GAP-LR] iter 18/20, agent 5/50, id=AGENT_00277, free_tasks=32
# [+   85.0s] [real_gap_vrp] [GAP-LR] iter 18/20, agent 10/50, id=AGENT_00516, free_tasks=31
# [+   85.2s] [real_gap_vrp] [GAP-LR] iter 18/20, agent 15/50, id=AGENT_00443, free_tasks=32
# [+   85.4s] [real_gap_vrp] [GAP-LR] iter 18/20, agent 20/50, id=AGENT_00392, free_tasks=31
# [+   85.7s] [real_gap_vrp] [GAP-LR] iter 18/20, agent 25/50, id=AGENT_00433, free_tasks=32
# [+   86.0s] [real_gap_vrp] [GAP-LR] iter 18/20, agent 30/50, id=AGENT_00344, free_tasks=32
# [+   86.3s] [real_gap_vrp] [GAP-LR] iter 18/20, agent 35/50, id=AGENT_00118, free_tasks=32
# [+   86.5s] [real_gap_vrp] [GAP-LR] iter 18/20, agent 40/50, id=AGENT_00117, free_tasks=32
# [+   86.8s] [real_gap_vrp] [GAP-LR] iter 18/20, agent 45/50, id=AGENT_00083, free_tasks=32
# [+   87.1s] [real_gap_vrp] [GAP-LR] iter 18/20, agent 50/50, id=AGENT_00030, free_tasks=32
# [+   87.1s] [real_gap_vrp] [GAP-LR] iter 18/20 done: LB=-2058.57, UB=inf, assigned=0/32, iter_sec=2.8
# [+   91.6s] [real_gap_vrp] [GAP-LR] iter 20/20 started
# [+   92.2s] [real_gap_vrp] [GAP-LR] iter 20/20, agent 5/50, id=AGENT_00277, free_tasks=32
# [+   92.7s] [real_gap_vrp] [GAP-LR] iter 20/20, agent 10/50, id=AGENT_00516, free_tasks=31
# [+   93.2s] [real_gap_vrp] [GAP-LR] iter 20/20, agent 15/50, id=AGENT_00443, free_tasks=32
# [+   93.6s] [real_gap_vrp] [GAP-LR] iter 20/20, agent 20/50, id=AGENT_00392, free_tasks=31
# [+   94.0s] [real_gap_vrp] [GAP-LR] iter 20/20, agent 25/50, id=AGENT_00433, free_tasks=32
# [+   94.5s] [real_gap_vrp] [GAP-LR] iter 20/20, agent 30/50, id=AGENT_00344, free_tasks=32
# [+   95.1s] [real_gap_vrp] [GAP-LR] iter 20/20, agent 35/50, id=AGENT_00118, free_tasks=32
# [+   95.5s] [real_gap_vrp] [GAP-LR] iter 20/20, agent 40/50, id=AGENT_00117, free_tasks=32
# [+   95.8s] [real_gap_vrp] [GAP-LR] iter 20/20, agent 45/50, id=AGENT_00083, free_tasks=32
# [+   96.1s] [real_gap_vrp] [GAP-LR] iter 20/20, agent 50/50, id=AGENT_00030, free_tasks=32
# [+   96.1s] [real_gap_vrp] [GAP-LR] iter 20/20 done: LB=-2058.57, UB=inf, assigned=0/32, iter_sec=4.5
# [+   96.1s] [real_gap_vrp] [GAP-LR] no feasible dual assignment found, run greedy repair
# [+   96.2s] [real_gap_vrp] [GAP-LR] gap allocation ready
# [+   96.2s] [real_gap_vrp] [GAP-VRP] step2 done in 69.6s, assigned_after_gap=32/32
# [+   96.2s] [real_gap_vrp] [GAP-VRP] step3: VRP build + validation
# [+   97.3s] [real_gap_vrp] [GAP-VRP] step3 progress: agents=1/6, routes=5, unassigned=0
# [+   98.7s] [real_gap_vrp] [GAP-VRP] step3 progress: agents=2/6, routes=15, unassigned=0
# [+   98.8s] [real_gap_vrp] [GAP-VRP] step3 progress: agents=3/6, routes=18, unassigned=0
# [+   98.8s] [real_gap_vrp] [GAP-VRP] step3 progress: agents=4/6, routes=19, unassigned=0
# [+   99.0s] [real_gap_vrp] [GAP-VRP] step3 progress: agents=5/6, routes=26, unassigned=0
# [+   99.1s] [real_gap_vrp] [GAP-VRP] step3 progress: agents=6/6, routes=32, unassigned=0
# [+  102.1s] [real_gap_vrp] [GAP-VRP] step3 done in 5.9s, routes=32, unassigned=0, violations=0
# [+  102.1s] [real_gap_vrp] [GAP-VRP] total runtime: 99.9s
# [+  102.1s] [real_gap_vrp] solver done in 99.9s
# [+  102.7s] GAP-VRP: DONE in 102.7s
# [+  102.7s] GAP-VRP-ALNS: START
# [+  102.7s] [real_gap_vrp_alns] load dataset: C:\Users\Пользователь\Optimization-of-flows-3\src\data\real\day_load_profiles\u50\fast_uniform\dataset_real_spb_day_u50_fast_f10.json
# [+  104.1s] [real_gap_vrp_alns] dataset loaded (nodes=46730, edges=127100, agents=50, tasks=32)
# [+  104.1s] [real_gap_vrp_alns] build nx graph
# [+  104.8s] [real_gap_vrp_alns] solver start
# [+  104.8s] [real_gap_vrp_alns] [GAP-VRP-ALNS] base solver start
# [+  104.8s] [real_gap_vrp_alns] [GAP-step1] LP setup: sources=32, sinks=9, variables=288, total_waste_tons=37.617
# [+  105.3s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=1/32, elapsed=0.6s
# [+  105.9s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=2/32, elapsed=1.1s
# [+  106.3s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=3/32, elapsed=1.6s
# [+  106.9s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=4/32, elapsed=2.2s
# [+  107.8s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=5/32, elapsed=3.1s
# [+  108.2s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=6/32, elapsed=3.5s
# [+  108.8s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=7/32, elapsed=4.0s
# [+  109.3s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=8/32, elapsed=4.6s
# [+  109.9s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=9/32, elapsed=5.2s
# [+  110.7s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=10/32, elapsed=5.9s
# [+  111.1s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=11/32, elapsed=6.4s
# [+  111.6s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=12/32, elapsed=6.8s
# [+  112.2s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=13/32, elapsed=7.4s
# [+  112.7s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=14/32, elapsed=7.9s
# [+  113.2s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=15/32, elapsed=8.4s
# [+  113.6s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=16/32, elapsed=8.8s
# [+  114.3s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=17/32, elapsed=9.6s
# [+  114.9s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=18/32, elapsed=10.1s
# [+  115.4s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=19/32, elapsed=10.7s
# [+  116.1s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=20/32, elapsed=11.3s
# [+  117.0s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=21/32, elapsed=12.2s
# [+  118.0s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=22/32, elapsed=13.2s
# [+  118.6s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=23/32, elapsed=13.9s
# [+  119.5s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=24/32, elapsed=14.7s
# [+  120.1s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=25/32, elapsed=15.3s
# [+  121.2s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=26/32, elapsed=16.4s
# [+  123.2s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=27/32, elapsed=18.5s
# [+  124.4s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=28/32, elapsed=19.6s
# [+  125.5s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=29/32, elapsed=20.8s
# [+  126.6s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=30/32, elapsed=21.9s
# [+  128.0s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=31/32, elapsed=23.3s
# [+  129.7s] [real_gap_vrp_alns] [GAP-step1] distance matrix: sources=32/32, elapsed=25.0s
# [+  129.7s] [real_gap_vrp_alns] [GAP-step1] distance matrix built in 25.0s
# [+  129.7s] [real_gap_vrp_alns] [GAP-step1] LP eq constraints built: 32 rows in 0.0s
# [+  129.7s] [real_gap_vrp_alns] [GAP-step1] LP ub constraints built: 9 rows in 0.0s
# [+  129.7s] [real_gap_vrp_alns] [GAP-step1] linprog start: method=highs
# [+  129.7s] [real_gap_vrp_alns] [GAP-step1] linprog done in 0.0s: success=True, status=0
# [+  129.7s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=1/32, tasks=1, elapsed=0.0s
# [+  129.7s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=2/32, tasks=2, elapsed=0.0s
# [+  129.7s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=3/32, tasks=3, elapsed=0.0s
# [+  129.7s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=4/32, tasks=4, elapsed=0.0s
# [+  129.7s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=5/32, tasks=5, elapsed=0.0s
# [+  129.7s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=6/32, tasks=6, elapsed=0.0s
# [+  129.7s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=7/32, tasks=7, elapsed=0.0s
# [+  129.7s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=8/32, tasks=8, elapsed=0.0s
# [+  129.7s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=9/32, tasks=9, elapsed=0.0s
# [+  129.7s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=10/32, tasks=10, elapsed=0.0s
# [+  129.7s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=11/32, tasks=11, elapsed=0.0s
# [+  129.7s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=12/32, tasks=12, elapsed=0.0s
# [+  129.7s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=13/32, tasks=13, elapsed=0.0s
# [+  129.7s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=14/32, tasks=14, elapsed=0.0s
# [+  129.8s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=15/32, tasks=15, elapsed=0.0s
# [+  129.8s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=16/32, tasks=16, elapsed=0.0s
# [+  129.8s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=17/32, tasks=17, elapsed=0.0s
# [+  129.8s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=18/32, tasks=18, elapsed=0.0s
# [+  129.8s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=19/32, tasks=19, elapsed=0.0s
# [+  129.8s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=20/32, tasks=20, elapsed=0.0s
# [+  129.8s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=21/32, tasks=21, elapsed=0.0s
# [+  129.8s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=22/32, tasks=22, elapsed=0.0s
# [+  129.8s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=23/32, tasks=23, elapsed=0.0s
# [+  129.8s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=24/32, tasks=24, elapsed=0.0s
# [+  129.8s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=25/32, tasks=25, elapsed=0.0s
# [+  129.8s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=26/32, tasks=26, elapsed=0.0s
# [+  129.8s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=27/32, tasks=27, elapsed=0.0s
# [+  129.8s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=28/32, tasks=28, elapsed=0.0s
# [+  129.8s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=29/32, tasks=29, elapsed=0.0s
# [+  129.8s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=30/32, tasks=30, elapsed=0.0s
# [+  129.8s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=31/32, tasks=31, elapsed=0.0s
# [+  129.8s] [real_gap_vrp_alns] [GAP-step1] build tasks: sources=32/32, tasks=32, elapsed=0.0s
# [+  129.8s] [real_gap_vrp_alns] [GAP-step1] step1 LP tasks built: tasks=32, elapsed=0.0s
# [+  129.8s] [real_gap_vrp_alns] [GAP-LR] prepare matrices: agents=50, tasks=32, max_iter=20
# [+  131.9s] [real_gap_vrp_alns] [GAP-LR] precompute costs: 5/50 agents
# [+  135.1s] [real_gap_vrp_alns] [GAP-LR] precompute costs: 10/50 agents
# [+  135.1s] [real_gap_vrp_alns] [GAP-LR] precompute costs: 15/50 agents
# [+  135.1s] [real_gap_vrp_alns] [GAP-LR] precompute costs: 20/50 agents
# [+  135.1s] [real_gap_vrp_alns] [GAP-LR] precompute costs: 25/50 agents
# [+  137.5s] [real_gap_vrp_alns] [GAP-LR] precompute costs: 30/50 agents
# [+  140.6s] [real_gap_vrp_alns] [GAP-LR] precompute costs: 35/50 agents
# [+  140.6s] [real_gap_vrp_alns] [GAP-LR] precompute costs: 40/50 agents
# [+  140.6s] [real_gap_vrp_alns] [GAP-LR] precompute costs: 45/50 agents
# [+  140.6s] [real_gap_vrp_alns] [GAP-LR] precompute costs: 50/50 agents
# [+  140.6s] [real_gap_vrp_alns] [GAP-LR] precompute done
# [+  140.6s] [real_gap_vrp_alns] [GAP-LR] iter 1/20 started
# [+  141.3s] [real_gap_vrp_alns] [GAP-LR] iter 1/20, agent 5/50, id=AGENT_00277, free_tasks=32
# [+  141.9s] [real_gap_vrp_alns] [GAP-LR] iter 1/20, agent 10/50, id=AGENT_00516, free_tasks=31
# [+  142.3s] [real_gap_vrp_alns] [GAP-LR] iter 1/20, agent 15/50, id=AGENT_00443, free_tasks=32
# [+  142.8s] [real_gap_vrp_alns] [GAP-LR] iter 1/20, agent 20/50, id=AGENT_00392, free_tasks=31
# [+  143.3s] [real_gap_vrp_alns] [GAP-LR] iter 1/20, agent 25/50, id=AGENT_00433, free_tasks=32
# [+  143.8s] [real_gap_vrp_alns] [GAP-LR] iter 1/20, agent 30/50, id=AGENT_00344, free_tasks=32
# [+  144.4s] [real_gap_vrp_alns] [GAP-LR] iter 1/20, agent 35/50, id=AGENT_00118, free_tasks=32
# [+  144.9s] [real_gap_vrp_alns] [GAP-LR] iter 1/20, agent 40/50, id=AGENT_00117, free_tasks=32
# [+  145.5s] [real_gap_vrp_alns] [GAP-LR] iter 1/20, agent 45/50, id=AGENT_00083, free_tasks=32
# [+  146.1s] [real_gap_vrp_alns] [GAP-LR] iter 1/20, agent 50/50, id=AGENT_00030, free_tasks=32
# [+  146.1s] [real_gap_vrp_alns] [GAP-LR] iter 1/20 done: LB=1302.80, UB=inf, assigned=0/32, iter_sec=5.5
# [+  146.1s] [real_gap_vrp_alns] [GAP-LR] iter 2/20 started
# [+  146.7s] [real_gap_vrp_alns] [GAP-LR] iter 2/20, agent 5/50, id=AGENT_00277, free_tasks=32
# [+  147.3s] [real_gap_vrp_alns] [GAP-LR] iter 2/20, agent 10/50, id=AGENT_00516, free_tasks=31
# [+  147.8s] [real_gap_vrp_alns] [GAP-LR] iter 2/20, agent 15/50, id=AGENT_00443, free_tasks=32
# [+  148.2s] [real_gap_vrp_alns] [GAP-LR] iter 2/20, agent 20/50, id=AGENT_00392, free_tasks=31
# [+  148.6s] [real_gap_vrp_alns] [GAP-LR] iter 2/20, agent 25/50, id=AGENT_00433, free_tasks=32
# [+  149.1s] [real_gap_vrp_alns] [GAP-LR] iter 2/20, agent 30/50, id=AGENT_00344, free_tasks=32
# [+  149.7s] [real_gap_vrp_alns] [GAP-LR] iter 2/20, agent 35/50, id=AGENT_00118, free_tasks=32
# [+  150.3s] [real_gap_vrp_alns] [GAP-LR] iter 2/20, agent 40/50, id=AGENT_00117, free_tasks=32
# [+  150.9s] [real_gap_vrp_alns] [GAP-LR] iter 2/20, agent 45/50, id=AGENT_00083, free_tasks=32
# [+  151.4s] [real_gap_vrp_alns] [GAP-LR] iter 2/20, agent 50/50, id=AGENT_00030, free_tasks=32
# [+  151.4s] [real_gap_vrp_alns] [GAP-LR] iter 2/20 done: LB=-2058.57, UB=inf, assigned=0/32, iter_sec=5.3
# [+  158.1s] [real_gap_vrp_alns] [GAP-LR] iter 4/20 started
# [+  158.9s] [real_gap_vrp_alns] [GAP-LR] iter 4/20, agent 5/50, id=AGENT_00277, free_tasks=32
# [+  159.5s] [real_gap_vrp_alns] [GAP-LR] iter 4/20, agent 10/50, id=AGENT_00516, free_tasks=31
# [+  160.0s] [real_gap_vrp_alns] [GAP-LR] iter 4/20, agent 15/50, id=AGENT_00443, free_tasks=32
# [+  160.6s] [real_gap_vrp_alns] [GAP-LR] iter 4/20, agent 20/50, id=AGENT_00392, free_tasks=31
# [+  161.1s] [real_gap_vrp_alns] [GAP-LR] iter 4/20, agent 25/50, id=AGENT_00433, free_tasks=32
# [+  161.8s] [real_gap_vrp_alns] [GAP-LR] iter 4/20, agent 30/50, id=AGENT_00344, free_tasks=32
# [+  162.5s] [real_gap_vrp_alns] [GAP-LR] iter 4/20, agent 35/50, id=AGENT_00118, free_tasks=32
# [+  163.2s] [real_gap_vrp_alns] [GAP-LR] iter 4/20, agent 40/50, id=AGENT_00117, free_tasks=32
# [+  163.9s] [real_gap_vrp_alns] [GAP-LR] iter 4/20, agent 45/50, id=AGENT_00083, free_tasks=32
# [+  164.6s] [real_gap_vrp_alns] [GAP-LR] iter 4/20, agent 50/50, id=AGENT_00030, free_tasks=32
# [+  164.6s] [real_gap_vrp_alns] [GAP-LR] iter 4/20 done: LB=-2058.57, UB=inf, assigned=0/32, iter_sec=6.5
# [+  171.1s] [real_gap_vrp_alns] [GAP-LR] iter 6/20 started
# [+  171.9s] [real_gap_vrp_alns] [GAP-LR] iter 6/20, agent 5/50, id=AGENT_00277, free_tasks=32
# [+  172.6s] [real_gap_vrp_alns] [GAP-LR] iter 6/20, agent 10/50, id=AGENT_00516, free_tasks=31
# [+  173.1s] [real_gap_vrp_alns] [GAP-LR] iter 6/20, agent 15/50, id=AGENT_00443, free_tasks=32
# [+  173.6s] [real_gap_vrp_alns] [GAP-LR] iter 6/20, agent 20/50, id=AGENT_00392, free_tasks=31
# [+  174.1s] [real_gap_vrp_alns] [GAP-LR] iter 6/20, agent 25/50, id=AGENT_00433, free_tasks=32
# [+  174.8s] [real_gap_vrp_alns] [GAP-LR] iter 6/20, agent 30/50, id=AGENT_00344, free_tasks=32
# [+  175.6s] [real_gap_vrp_alns] [GAP-LR] iter 6/20, agent 35/50, id=AGENT_00118, free_tasks=32
# [+  176.2s] [real_gap_vrp_alns] [GAP-LR] iter 6/20, agent 40/50, id=AGENT_00117, free_tasks=32
# [+  177.0s] [real_gap_vrp_alns] [GAP-LR] iter 6/20, agent 45/50, id=AGENT_00083, free_tasks=32
# [+  177.7s] [real_gap_vrp_alns] [GAP-LR] iter 6/20, agent 50/50, id=AGENT_00030, free_tasks=32
# [+  177.7s] [real_gap_vrp_alns] [GAP-LR] iter 6/20 done: LB=-2058.57, UB=inf, assigned=0/32, iter_sec=6.6
# [+  184.1s] [real_gap_vrp_alns] [GAP-LR] iter 8/20 started
# [+  184.7s] [real_gap_vrp_alns] [GAP-LR] iter 8/20, agent 5/50, id=AGENT_00277, free_tasks=32
# [+  185.4s] [real_gap_vrp_alns] [GAP-LR] iter 8/20, agent 10/50, id=AGENT_00516, free_tasks=31
# [+  185.9s] [real_gap_vrp_alns] [GAP-LR] iter 8/20, agent 15/50, id=AGENT_00443, free_tasks=32
# [+  186.4s] [real_gap_vrp_alns] [GAP-LR] iter 8/20, agent 20/50, id=AGENT_00392, free_tasks=31
# [+  186.9s] [real_gap_vrp_alns] [GAP-LR] iter 8/20, agent 25/50, id=AGENT_00433, free_tasks=32
# [+  187.4s] [real_gap_vrp_alns] [GAP-LR] iter 8/20, agent 30/50, id=AGENT_00344, free_tasks=32
# [+  188.1s] [real_gap_vrp_alns] [GAP-LR] iter 8/20, agent 35/50, id=AGENT_00118, free_tasks=32
# [+  188.7s] [real_gap_vrp_alns] [GAP-LR] iter 8/20, agent 40/50, id=AGENT_00117, free_tasks=32
# [+  189.4s] [real_gap_vrp_alns] [GAP-LR] iter 8/20, agent 45/50, id=AGENT_00083, free_tasks=32
# [+  189.9s] [real_gap_vrp_alns] [GAP-LR] iter 8/20, agent 50/50, id=AGENT_00030, free_tasks=32
# [+  189.9s] [real_gap_vrp_alns] [GAP-LR] iter 8/20 done: LB=-2058.57, UB=inf, assigned=0/32, iter_sec=5.8
# [+  195.4s] [real_gap_vrp_alns] [GAP-LR] iter 10/20 started
# [+  196.1s] [real_gap_vrp_alns] [GAP-LR] iter 10/20, agent 5/50, id=AGENT_00277, free_tasks=32
# [+  196.7s] [real_gap_vrp_alns] [GAP-LR] iter 10/20, agent 10/50, id=AGENT_00516, free_tasks=31
# [+  197.3s] [real_gap_vrp_alns] [GAP-LR] iter 10/20, agent 15/50, id=AGENT_00443, free_tasks=32
# [+  197.7s] [real_gap_vrp_alns] [GAP-LR] iter 10/20, agent 20/50, id=AGENT_00392, free_tasks=31
# [+  198.1s] [real_gap_vrp_alns] [GAP-LR] iter 10/20, agent 25/50, id=AGENT_00433, free_tasks=32
# [+  198.6s] [real_gap_vrp_alns] [GAP-LR] iter 10/20, agent 30/50, id=AGENT_00344, free_tasks=32
# [+  199.1s] [real_gap_vrp_alns] [GAP-LR] iter 10/20, agent 35/50, id=AGENT_00118, free_tasks=32
# [+  199.6s] [real_gap_vrp_alns] [GAP-LR] iter 10/20, agent 40/50, id=AGENT_00117, free_tasks=32
# [+  200.2s] [real_gap_vrp_alns] [GAP-LR] iter 10/20, agent 45/50, id=AGENT_00083, free_tasks=32
# [+  200.6s] [real_gap_vrp_alns] [GAP-LR] iter 10/20, agent 50/50, id=AGENT_00030, free_tasks=32
# [+  200.7s] [real_gap_vrp_alns] [GAP-LR] iter 10/20 done: LB=-2058.57, UB=inf, assigned=0/32, iter_sec=5.3
# [+  206.7s] [real_gap_vrp_alns] [GAP-LR] iter 12/20 started
# [+  207.4s] [real_gap_vrp_alns] [GAP-LR] iter 12/20, agent 5/50, id=AGENT_00277, free_tasks=32
# [+  208.0s] [real_gap_vrp_alns] [GAP-LR] iter 12/20, agent 10/50, id=AGENT_00516, free_tasks=31
# [+  208.6s] [real_gap_vrp_alns] [GAP-LR] iter 12/20, agent 15/50, id=AGENT_00443, free_tasks=32
# [+  209.0s] [real_gap_vrp_alns] [GAP-LR] iter 12/20, agent 20/50, id=AGENT_00392, free_tasks=31
# [+  209.5s] [real_gap_vrp_alns] [GAP-LR] iter 12/20, agent 25/50, id=AGENT_00433, free_tasks=32
# [+  210.1s] [real_gap_vrp_alns] [GAP-LR] iter 12/20, agent 30/50, id=AGENT_00344, free_tasks=32
# [+  210.8s] [real_gap_vrp_alns] [GAP-LR] iter 12/20, agent 35/50, id=AGENT_00118, free_tasks=32
# [+  211.4s] [real_gap_vrp_alns] [GAP-LR] iter 12/20, agent 40/50, id=AGENT_00117, free_tasks=32
# [+  212.0s] [real_gap_vrp_alns] [GAP-LR] iter 12/20, agent 45/50, id=AGENT_00083, free_tasks=32
# [+  212.6s] [real_gap_vrp_alns] [GAP-LR] iter 12/20, agent 50/50, id=AGENT_00030, free_tasks=32
# [+  212.6s] [real_gap_vrp_alns] [GAP-LR] iter 12/20 done: LB=-2058.57, UB=inf, assigned=0/32, iter_sec=5.9
# [+  218.0s] [real_gap_vrp_alns] [GAP-LR] iter 14/20 started
# [+  218.6s] [real_gap_vrp_alns] [GAP-LR] iter 14/20, agent 5/50, id=AGENT_00277, free_tasks=32
# [+  219.2s] [real_gap_vrp_alns] [GAP-LR] iter 14/20, agent 10/50, id=AGENT_00516, free_tasks=31
# [+  219.7s] [real_gap_vrp_alns] [GAP-LR] iter 14/20, agent 15/50, id=AGENT_00443, free_tasks=32
# [+  220.1s] [real_gap_vrp_alns] [GAP-LR] iter 14/20, agent 20/50, id=AGENT_00392, free_tasks=31
# [+  220.6s] [real_gap_vrp_alns] [GAP-LR] iter 14/20, agent 25/50, id=AGENT_00433, free_tasks=32
# [+  221.1s] [real_gap_vrp_alns] [GAP-LR] iter 14/20, agent 30/50, id=AGENT_00344, free_tasks=32
# [+  221.7s] [real_gap_vrp_alns] [GAP-LR] iter 14/20, agent 35/50, id=AGENT_00118, free_tasks=32
# [+  222.3s] [real_gap_vrp_alns] [GAP-LR] iter 14/20, agent 40/50, id=AGENT_00117, free_tasks=32
# [+  222.8s] [real_gap_vrp_alns] [GAP-LR] iter 14/20, agent 45/50, id=AGENT_00083, free_tasks=32
# [+  223.4s] [real_gap_vrp_alns] [GAP-LR] iter 14/20, agent 50/50, id=AGENT_00030, free_tasks=32
# [+  223.4s] [real_gap_vrp_alns] [GAP-LR] iter 14/20 done: LB=-2058.57, UB=inf, assigned=0/32, iter_sec=5.4
# [+  228.7s] [real_gap_vrp_alns] [GAP-LR] iter 16/20 started
# [+  229.3s] [real_gap_vrp_alns] [GAP-LR] iter 16/20, agent 5/50, id=AGENT_00277, free_tasks=32
# [+  229.9s] [real_gap_vrp_alns] [GAP-LR] iter 16/20, agent 10/50, id=AGENT_00516, free_tasks=31
# [+  230.4s] [real_gap_vrp_alns] [GAP-LR] iter 16/20, agent 15/50, id=AGENT_00443, free_tasks=32
# [+  230.8s] [real_gap_vrp_alns] [GAP-LR] iter 16/20, agent 20/50, id=AGENT_00392, free_tasks=31
# [+  231.4s] [real_gap_vrp_alns] [GAP-LR] iter 16/20, agent 25/50, id=AGENT_00433, free_tasks=32
# [+  231.9s] [real_gap_vrp_alns] [GAP-LR] iter 16/20, agent 30/50, id=AGENT_00344, free_tasks=32
# [+  232.5s] [real_gap_vrp_alns] [GAP-LR] iter 16/20, agent 35/50, id=AGENT_00118, free_tasks=32
# [+  233.0s] [real_gap_vrp_alns] [GAP-LR] iter 16/20, agent 40/50, id=AGENT_00117, free_tasks=32
# [+  233.6s] [real_gap_vrp_alns] [GAP-LR] iter 16/20, agent 45/50, id=AGENT_00083, free_tasks=32
# [+  234.1s] [real_gap_vrp_alns] [GAP-LR] iter 16/20, agent 50/50, id=AGENT_00030, free_tasks=32
# [+  234.1s] [real_gap_vrp_alns] [GAP-LR] iter 16/20 done: LB=-2058.57, UB=inf, assigned=0/32, iter_sec=5.4
# [+  239.1s] [real_gap_vrp_alns] [GAP-LR] iter 18/20 started
# [+  239.7s] [real_gap_vrp_alns] [GAP-LR] iter 18/20, agent 5/50, id=AGENT_00277, free_tasks=32
# [+  240.2s] [real_gap_vrp_alns] [GAP-LR] iter 18/20, agent 10/50, id=AGENT_00516, free_tasks=31
# [+  240.7s] [real_gap_vrp_alns] [GAP-LR] iter 18/20, agent 15/50, id=AGENT_00443, free_tasks=32
# [+  241.1s] [real_gap_vrp_alns] [GAP-LR] iter 18/20, agent 20/50, id=AGENT_00392, free_tasks=31
# [+  241.5s] [real_gap_vrp_alns] [GAP-LR] iter 18/20, agent 25/50, id=AGENT_00433, free_tasks=32
# [+  242.0s] [real_gap_vrp_alns] [GAP-LR] iter 18/20, agent 30/50, id=AGENT_00344, free_tasks=32
# [+  242.6s] [real_gap_vrp_alns] [GAP-LR] iter 18/20, agent 35/50, id=AGENT_00118, free_tasks=32
# [+  243.1s] [real_gap_vrp_alns] [GAP-LR] iter 18/20, agent 40/50, id=AGENT_00117, free_tasks=32
# [+  243.6s] [real_gap_vrp_alns] [GAP-LR] iter 18/20, agent 45/50, id=AGENT_00083, free_tasks=32
# [+  244.2s] [real_gap_vrp_alns] [GAP-LR] iter 18/20, agent 50/50, id=AGENT_00030, free_tasks=32
# [+  244.2s] [real_gap_vrp_alns] [GAP-LR] iter 18/20 done: LB=-2058.57, UB=inf, assigned=0/32, iter_sec=5.1
# [+  247.3s] [real_gap_vrp_alns] [GAP-LR] iter 20/20 started
# [+  247.7s] [real_gap_vrp_alns] [GAP-LR] iter 20/20, agent 5/50, id=AGENT_00277, free_tasks=32
# [+  248.0s] [real_gap_vrp_alns] [GAP-LR] iter 20/20, agent 10/50, id=AGENT_00516, free_tasks=31
# [+  248.2s] [real_gap_vrp_alns] [GAP-LR] iter 20/20, agent 15/50, id=AGENT_00443, free_tasks=32
# [+  248.4s] [real_gap_vrp_alns] [GAP-LR] iter 20/20, agent 20/50, id=AGENT_00392, free_tasks=31
# [+  248.6s] [real_gap_vrp_alns] [GAP-LR] iter 20/20, agent 25/50, id=AGENT_00433, free_tasks=32
# [+  248.9s] [real_gap_vrp_alns] [GAP-LR] iter 20/20, agent 30/50, id=AGENT_00344, free_tasks=32
# [+  249.3s] [real_gap_vrp_alns] [GAP-LR] iter 20/20, agent 35/50, id=AGENT_00118, free_tasks=32
# [+  249.5s] [real_gap_vrp_alns] [GAP-LR] iter 20/20, agent 40/50, id=AGENT_00117, free_tasks=32
# [+  249.8s] [real_gap_vrp_alns] [GAP-LR] iter 20/20, agent 45/50, id=AGENT_00083, free_tasks=32
# [+  250.1s] [real_gap_vrp_alns] [GAP-LR] iter 20/20, agent 50/50, id=AGENT_00030, free_tasks=32
# [+  250.1s] [real_gap_vrp_alns] [GAP-LR] iter 20/20 done: LB=-2058.57, UB=inf, assigned=0/32, iter_sec=2.8
# [+  250.1s] [real_gap_vrp_alns] [GAP-LR] no feasible dual assignment found, run greedy repair
# [+  250.1s] [real_gap_vrp_alns] [GAP-LR] gap allocation ready
# [+  267.2s] [real_gap_vrp_alns] [GAP-VRP-ALNS] base solution objective=932.842
# [+  267.2s] [real_gap_vrp_alns] [GAP-VRP-ALNS] ALNS start: iterations=20, removal_q=5, seed=42
# [+  331.9s] [real_gap_vrp_alns] [GAP-VRP-ALNS] ALNS iter 10/20: candidate objective=883.413, unassigned=0
# [+  402.3s] [real_gap_vrp_alns] [GAP-VRP-ALNS] ALNS iter 20/20: candidate objective=882.485, unassigned=0
# [+  402.6s] [real_gap_vrp_alns] [GAP-VRP-ALNS] ALNS done: best objective=877.338
# [+  410.4s] [real_gap_vrp_alns] solver done in 305.7s
# [+  411.1s] GAP-VRP-ALNS: DONE in 308.5s
# [+  411.1s] REAL-MILP: START
# [+  411.1s] [real_milp] load dataset: C:\Users\Пользователь\Optimization-of-flows-3\src\data\real\day_load_profiles\u50\fast_uniform\dataset_real_spb_day_u50_fast_f10.json
# [+  413.2s] [real_milp] dataset loaded (nodes=46730, edges=127100, agents=50, tasks=32)
# [+  413.2s] [real_milp] build nx graph
# [+  414.1s] [real_milp] solver start
# [+  414.1s] [real_milp] prepare problem: tasks=32, agents=50
# [+  416.0s] [real_milp] compatible pairs: 3/32 tasks processed, pairs=150
# [+  417.7s] [real_milp] compatible pairs: 6/32 tasks processed, pairs=300
# [+  418.9s] [real_milp] compatible pairs: 9/32 tasks processed, pairs=450
# [+  421.0s] [real_milp] compatible pairs: 12/32 tasks processed, pairs=600
# [+  422.2s] [real_milp] compatible pairs: 15/32 tasks processed, pairs=750
# [+  423.8s] [real_milp] compatible pairs: 18/32 tasks processed, pairs=900
# [+  424.7s] [real_milp] compatible pairs: 21/32 tasks processed, pairs=1050
# [+  426.6s] [real_milp] compatible pairs: 24/32 tasks processed, pairs=1192
# [+  428.0s] [real_milp] compatible pairs: 27/32 tasks processed, pairs=1342
# [+  429.8s] [real_milp] compatible pairs: 30/32 tasks processed, pairs=1492
# [+  432.1s] [real_milp] compatible pairs: 32/32 tasks processed, pairs=1592
# [+  432.1s] [real_milp] pair matrix ready in 18.0s
# [+  432.1s] [real_milp] build MILP matrices: vars=1624, constraints=132
# [+  432.1s] [real_milp] solve MILP (time_limit=90s)
# [+  432.3s] [real_milp] MILP solved in 0.2s (status=0)
# [+  432.3s] [real_milp] decode solution: assigned_tasks=32, unassigned=0
# [+  477.9s] [real_milp] finalize in 63.9s: routes=32, unassigned=0, violations=0, feasible=True
# [+  477.9s] [real_milp] solver done in 63.9s
# [+  493.5s] REAL-MILP: DONE in 82.3s
# [+  493.5s] REAL-GENETIC: START
# [+  493.5s] [real_genetic] load dataset: C:\Users\Пользователь\Optimization-of-flows-3\src\data\real\day_load_profiles\u50\fast_uniform\dataset_real_spb_day_u50_fast_f10.json
# [+  494.9s] [real_genetic] dataset loaded (nodes=46730, edges=127100, agents=50, tasks=32)
# [+  494.9s] [real_genetic] build nx graph
# [+  495.6s] [real_genetic] solver start
# [+  495.6s] [real_genetic] start: tasks=32, agents=50, population=20, generations=20
# [+  495.6s] [real_genetic] start assignment: tasks=32, agents=50, population=20, generations=20
# [+  495.6s] [real_genetic] population initialized: 20 chromosomes
# [+  550.4s] [real_genetic] generation 2/20, best_cost=1989.186
# [+  564.5s] [real_genetic] generation 4/20, best_cost=1989.186
# [+  577.6s] [real_genetic] generation 6/20, best_cost=1989.186
# [+  583.2s] [real_genetic] generation 8/20, best_cost=1989.186
# [+  588.7s] [real_genetic] generation 10/20, best_cost=1989.186
# [+  594.5s] [real_genetic] generation 12/20, best_cost=1989.186
# [+  600.3s] [real_genetic] generation 14/20, best_cost=1989.186
# [+  605.8s] [real_genetic] generation 16/20, best_cost=1989.186
# [+  611.4s] [real_genetic] generation 18/20, best_cost=1989.186
# [+  617.0s] [real_genetic] generation 20/20, best_cost=1989.186
# [+  617.1s] [real_genetic] chromosome decoded: assigned_tasks=32, unassigned=0
# [+  617.1s] [real_genetic] routes built: routes=32, active_agents=32
# [+  617.1s] [real_genetic] assignment done in 121.6s: routes=32, unassigned=0
# [+  671.9s] [real_genetic] finalize: violations=0, feasible=True
# [+  671.9s] [real_genetic] solver done in 176.3s
# [+  690.0s] REAL-GENETIC: DONE in 196.6s
# [+  690.0s] GAP-VRP-SAA: START
# [+  690.0s] [real_gap_vrp_saa] load dataset: C:\Users\Пользователь\Optimization-of-flows-3\src\data\real\day_load_profiles\u50\fast_uniform\dataset_real_spb_day_u50_fast_f10.json
# [+  691.4s] [real_gap_vrp_saa] dataset loaded (nodes=46730, edges=127100, agents=50, tasks=32)
# [+  691.4s] [real_gap_vrp_saa] build nx graph
# [+  692.0s] [real_gap_vrp_saa] solver start
# [+  692.0s] [real_gap_vrp_saa] [GAP-VRP-SAA] step1 start
# [+  692.0s] [real_gap_vrp_saa] [GAP-step1] LP setup: sources=32, sinks=9, variables=288, total_waste_tons=37.617
# [+  692.6s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=1/32, elapsed=0.5s
# [+  693.1s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=2/32, elapsed=1.1s
# [+  693.5s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=3/32, elapsed=1.5s
# [+  694.0s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=4/32, elapsed=1.9s
# [+  694.8s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=5/32, elapsed=2.8s
# [+  695.2s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=6/32, elapsed=3.2s
# [+  695.7s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=7/32, elapsed=3.6s
# [+  696.2s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=8/32, elapsed=4.1s
# [+  696.7s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=9/32, elapsed=4.6s
# [+  697.4s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=10/32, elapsed=5.3s
# [+  697.8s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=11/32, elapsed=5.7s
# [+  698.1s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=12/32, elapsed=6.1s
# [+  698.6s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=13/32, elapsed=6.6s
# [+  699.0s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=14/32, elapsed=7.0s
# [+  699.4s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=15/32, elapsed=7.4s
# [+  699.8s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=16/32, elapsed=7.8s
# [+  700.5s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=17/32, elapsed=8.4s
# [+  700.9s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=18/32, elapsed=8.9s
# [+  701.4s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=19/32, elapsed=9.3s
# [+  701.9s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=20/32, elapsed=9.8s
# [+  702.7s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=21/32, elapsed=10.6s
# [+  703.2s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=22/32, elapsed=11.2s
# [+  703.6s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=23/32, elapsed=11.6s
# [+  704.1s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=24/32, elapsed=12.1s
# [+  704.5s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=25/32, elapsed=12.5s
# [+  705.5s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=26/32, elapsed=13.5s
# [+  706.1s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=27/32, elapsed=14.0s
# [+  706.7s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=28/32, elapsed=14.6s
# [+  707.3s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=29/32, elapsed=15.2s
# [+  708.1s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=30/32, elapsed=16.0s
# [+  709.9s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=31/32, elapsed=17.9s
# [+  712.1s] [real_gap_vrp_saa] [GAP-step1] distance matrix: sources=32/32, elapsed=20.0s
# [+  712.1s] [real_gap_vrp_saa] [GAP-step1] distance matrix built in 20.0s
# [+  712.1s] [real_gap_vrp_saa] [GAP-step1] LP eq constraints built: 32 rows in 0.0s
# [+  712.1s] [real_gap_vrp_saa] [GAP-step1] LP ub constraints built: 9 rows in 0.0s
# [+  712.1s] [real_gap_vrp_saa] [GAP-step1] linprog start: method=highs
# [+  712.1s] [real_gap_vrp_saa] [GAP-step1] linprog done in 0.1s: success=True, status=0
# [+  712.1s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=1/32, tasks=1, elapsed=0.0s
# [+  712.1s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=2/32, tasks=2, elapsed=0.0s
# [+  712.1s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=3/32, tasks=3, elapsed=0.0s
# [+  712.1s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=4/32, tasks=4, elapsed=0.0s
# [+  712.1s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=5/32, tasks=5, elapsed=0.0s
# [+  712.1s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=6/32, tasks=6, elapsed=0.0s
# [+  712.1s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=7/32, tasks=7, elapsed=0.0s
# [+  712.1s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=8/32, tasks=8, elapsed=0.0s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=9/32, tasks=9, elapsed=0.0s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=10/32, tasks=10, elapsed=0.0s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=11/32, tasks=11, elapsed=0.0s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=12/32, tasks=12, elapsed=0.0s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=13/32, tasks=13, elapsed=0.0s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=14/32, tasks=14, elapsed=0.0s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=15/32, tasks=15, elapsed=0.0s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=16/32, tasks=16, elapsed=0.0s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=17/32, tasks=17, elapsed=0.0s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=18/32, tasks=18, elapsed=0.1s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=19/32, tasks=19, elapsed=0.1s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=20/32, tasks=20, elapsed=0.1s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=21/32, tasks=21, elapsed=0.1s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=22/32, tasks=22, elapsed=0.1s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=23/32, tasks=23, elapsed=0.1s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=24/32, tasks=24, elapsed=0.1s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=25/32, tasks=25, elapsed=0.1s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=26/32, tasks=26, elapsed=0.1s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=27/32, tasks=27, elapsed=0.1s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=28/32, tasks=28, elapsed=0.1s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=29/32, tasks=29, elapsed=0.1s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=30/32, tasks=30, elapsed=0.1s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=31/32, tasks=31, elapsed=0.1s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] build tasks: sources=32/32, tasks=32, elapsed=0.1s
# [+  712.2s] [real_gap_vrp_saa] [GAP-step1] step1 LP tasks built: tasks=32, elapsed=0.1s
# [+  712.2s] [real_gap_vrp_saa] [GAP-VRP-SAA] step1 done: tasks=32
# [+  712.2s] [real_gap_vrp_saa] [GAP-VRP-SAA] SAA start: total_nodes=33, sample_size=12, iterations=60
# [+  712.2s] [real_gap_vrp_saa] [GAP-VRP-SAA] SAA iter 10/60: route_pool=20
# [+  712.2s] [real_gap_vrp_saa] [GAP-VRP-SAA] SAA iter 20/60: route_pool=40
# [+  712.2s] [real_gap_vrp_saa] [GAP-VRP-SAA] SAA iter 30/60: route_pool=60
# [+  712.2s] [real_gap_vrp_saa] [GAP-VRP-SAA] SAA iter 40/60: route_pool=80
# [+  712.2s] [real_gap_vrp_saa] [GAP-VRP-SAA] SAA iter 50/60: route_pool=100
# [+  712.2s] [real_gap_vrp_saa] [GAP-VRP-SAA] SAA iter 60/60: route_pool=120
# [+  712.2s] [real_gap_vrp_saa] [GAP-VRP-SAA] SAA assemble done: route_pool=120, assembled_routes=12
# [+  728.7s] [real_gap_vrp_saa] solver done in 36.7s
# [+  729.4s] GAP-VRP-SAA: DONE in 39.3s
# Saved: C:\Users\Пользователь\Optimization-of-flows-3\notebooks\local\real_data\u50_fast_uniform\f10\benchmark_u50_fast_alns_f10_20260416_094815.json
#            algorithm  feasible  all_checks_ok  assigned_routes  \
# 0  real_gap_vrp_alns      True           True               32
# 1       real_gap_vrp      True           True               32
# 2   real_gap_vrp_saa      True           True               32
# 3          real_milp      True           True               32
# 4       real_genetic      True           True               32
#
#    unassigned_tasks  active_agents  transport_work_ton_km  total_km  \
# 0                 0              5                419.865   877.338
# 1                 0              6                419.865   932.842
# 2                 0             12                419.865  1035.400
# 3                 0             23               1941.714  4510.761
# 4                 0             32               1941.714  4627.014
#
#    deadhead_km  deadhead_share_pct  total_hours  runtime_sec  alns_gain
# 0      501.182              57.125       43.596      305.670     55.504
# 1      556.686              59.676       45.908       99.905        NaN
# 2      659.243              63.670       47.719       36.694        NaN
# 3     2257.362              50.044      190.646       63.858        NaN
# 4     2373.615              51.299      195.709      176.336        NaN

# %%
# Schedule map (graph with route scheduling)
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import plotly.express as px

from flowopt.backend.io import load_dataset
from flowopt.solvers import gap_vrp_alns_solver, gap_vrp_saa_solver, real_gap_vrp_solver, real_milp_solver, real_genetic_solver
from flowopt import gap_vrp_solver as gap_core
from flowopt.dataset import RoutingDataset
import flowopt.core as core

SCHEDULE_ALGO = "real_genetic"  # real_gap_vrp | real_gap_vrp_alns | real_gap_vrp_saa | real_milp | real_genetic
MAP_INTERACTIVE = True
MAP_SHOW_SOLVER_PROGRESS = False

MAP_OUT_DIR = REPO_ROOT / "notebooks" / "local" / "real_data" / "u50_fast_uniform" / factor_tag
MAP_OUT_DIR.mkdir(parents=True, exist_ok=True)
SCHEDULE_MAP_PATH = MAP_OUT_DIR / f"schedule_map_{SCHEDULE_ALGO}_{factor_tag}.png"
SCHEDULE_PLAN_PATH = MAP_OUT_DIR / f"schedule_plan_{SCHEDULE_ALGO}_{factor_tag}.json"

# Re-run selected solver to get full routes/states object for rendering.
dataset_obj, payload_obj = load_dataset(DATASET_PATH)
graph_obj = core.build_nx_graph(dataset_obj)
cache_obj: dict[tuple[str, str], tuple[list[str], float] | None] = {}

if SCHEDULE_ALGO == "real_gap_vrp":
    solver_result = real_gap_vrp_solver.solve_real_gap_vrp(
        dataset=dataset_obj,
        payload=payload_obj,
        graph=graph_obj,
        cache=cache_obj,
        step1_method=GAP_STEP1_METHOD,
        gap_iter=GAP_ITER,
        use_repair=USE_REPAIR,
        show_progress=MAP_SHOW_SOLVER_PROGRESS,
        verbose=False,
    )
elif SCHEDULE_ALGO == "real_gap_vrp_alns":
    solver_bundle = gap_vrp_alns_solver.solve_real_gap_vrp_alns(
        dataset=dataset_obj,
        payload=payload_obj,
        graph=graph_obj,
        cache=cache_obj,
        step1_method=GAP_STEP1_METHOD,
        gap_iter=GAP_ITER,
        use_repair=USE_REPAIR,
        alns_iterations=ALNS_ITERATIONS,
        alns_removal_q=ALNS_REMOVAL_Q,
        alns_seed=ALNS_RANDOM_SEED,
        start_temperature=ALNS_START_TEMP,
        end_temperature=ALNS_END_TEMP,
        temperature_step=ALNS_STEP,
        show_progress=MAP_SHOW_SOLVER_PROGRESS,
        verbose=False,
    )
    solver_result = solver_bundle.result
elif SCHEDULE_ALGO == "real_milp":
    solver_result = real_milp_solver.solve_real_milp(
        dataset=dataset_obj,
        payload=payload_obj,
        graph=graph_obj,
        cache=cache_obj,
        time_limit_sec=RMILP_TIME_LIMIT_SEC,
        unassigned_penalty=RMILP_UNASSIGNED_PENALTY,
        show_progress=MAP_SHOW_SOLVER_PROGRESS,
    )
elif SCHEDULE_ALGO == "real_genetic":
    effective_generations = GA_GENERATIONS
    if GA_GENERATION_SCALE > 0:
        effective_generations = max(GA_MIN_GENERATIONS, int(round(GA_GENERATIONS * GA_GENERATION_SCALE)))
    solver_result = real_genetic_solver.solve_real_genetic(
        dataset=dataset_obj,
        payload=payload_obj,
        graph=graph_obj,
        cache=cache_obj,
        population_size=GA_POPULATION_SIZE,
        generations=effective_generations,
        elite_size=GA_ELITE_SIZE,
        seed=GA_SEED,
        show_progress=MAP_SHOW_SOLVER_PROGRESS,
    )

elif SCHEDULE_ALGO == "real_gap_vrp_saa":
    solver_bundle = gap_vrp_saa_solver.solve_real_gap_vrp_saa(
        dataset=dataset_obj,
        payload=payload_obj,
        graph=graph_obj,
        cache=cache_obj,
        step1_method=GAP_STEP1_METHOD,
        gap_iter=GAP_ITER,
        use_repair=USE_REPAIR,
        saa_sample_size=SAA_SAMPLE_SIZE,
        saa_iterations=SAA_ITERATIONS,
        saa_route_max_size=SAA_ROUTE_MAX_SIZE,
        saa_seed=SAA_SEED,
        saa_log_every=SAA_LOG_EVERY,
        show_progress=MAP_SHOW_SOLVER_PROGRESS,
        verbose=False,
    )
    solver_result = solver_bundle.result

else:
    raise ValueError(f"Unknown SCHEDULE_ALGO={SCHEDULE_ALGO}")

print(
    {
        "algorithm": SCHEDULE_ALGO,
        "assigned_routes": len(solver_result.routes),
        "unassigned": len(solver_result.unassigned),
        "active_agents": sum(1 for s in solver_result.states.values() if s.task_ids),
        "feasible": solver_result.feasible,
    }
)

if not solver_result.routes:
    raise RuntimeError("No routes in solver_result, schedule map cannot be rendered")

# GAP-based solvers use generated task ids (LP_T...), so for rendering switch task table to step1-generated tasks.
dataset_for_render = dataset_obj
route_task_ids = {tid for route in solver_result.routes for tid in route.task_ids}
base_task_ids = {t.task_id for t in dataset_obj.tasks}

gap_like_algos = {"real_gap_vrp", "real_gap_vrp_alns", "real_gap_vrp_saa"}
if not route_task_ids.issubset(base_task_ids):
    if SCHEDULE_ALGO not in gap_like_algos:
        missing = sorted(route_task_ids - base_task_ids)[:5]
        raise RuntimeError(f"Route task ids missing in dataset tasks: sample={missing}")

    if GAP_STEP1_METHOD == "lp":
        generated_tasks = gap_core.generate_tasks_lp(
            dataset_obj,
            graph_obj,
            cache_obj,
            show_progress=MAP_SHOW_SOLVER_PROGRESS,
        )
    else:
        generated_tasks = gap_core.generate_tasks_greedy(
            dataset_obj,
            graph_obj,
            cache_obj,
            show_progress=MAP_SHOW_SOLVER_PROGRESS,
        )

    generated_task_ids = {t.task_id for t in generated_tasks}
    if not route_task_ids.issubset(generated_task_ids):
        missing = sorted(route_task_ids - generated_task_ids)[:5]
        raise RuntimeError(f"Route task ids missing in generated step1 tasks: sample={missing}")

    dataset_for_render = RoutingDataset(
        graph=dataset_obj.graph,
        fleet=dataset_obj.fleet,
        tasks=generated_tasks,
        routes=dataset_obj.routes,
        metadata=dataset_obj.metadata,
    )
    print(
        "Render uses generated step1 tasks:",
        {"generated_tasks": len(generated_tasks), "method": GAP_STEP1_METHOD},
    )

core.render_solution_map(
    dataset_for_render,
    graph_obj,
    cache_obj,
    solver_result.routes,
    solver_result.states,
    SCHEDULE_MAP_PATH,
)

# Save route plan for further debug/replay.
plan_payload = core.build_solution_plan(
    solver_result.routes,
    dataset_for_render,
    solver_result.states,
)
SCHEDULE_PLAN_PATH.write_text(json.dumps(plan_payload, ensure_ascii=False, indent=2), encoding="utf-8")

print("Saved map :", SCHEDULE_MAP_PATH)
print("Saved plan:", SCHEDULE_PLAN_PATH)

img = mpimg.imread(SCHEDULE_MAP_PATH)
if MAP_INTERACTIVE:
    fig = px.imshow(img)
    fig.update_layout(
        width=1200,
        height=900,
        margin=dict(l=10, r=10, t=40, b=10),
        title=f"Schedule Map: {SCHEDULE_ALGO} ({factor_tag})",
    )
    fig.show()
else:
    plt.figure(figsize=(16, 12))
    plt.imshow(img)
    plt.axis("off")
    plt.title(f"Schedule Map: {SCHEDULE_ALGO} ({factor_tag})")
    plt.show()
# Out:
# {'algorithm': 'real_genetic', 'assigned_routes': 32, 'unassigned': 0, 'active_agents': 32, 'feasible': True}
# Saved map : C:\Users\Пользователь\Optimization-of-flows-3\notebooks\local\real_data\u50_fast_uniform\f10\schedule_map_real_genetic_f10.png
# Saved plan: C:\Users\Пользователь\Optimization-of-flows-3\notebooks\local\real_data\u50_fast_uniform\f10\schedule_plan_real_genetic_f10.json

# %%
# Optional detailed columns
detail_cols = [
    "algorithm",
    "checks",
    "solver_error",
    "step1_method",
    "gap_iter",
    "used_agents",
    "time_limit_sec",
    "unassigned_penalty",
    "population_size",
    "generations",
    "generations_requested",
    "generation_scale",
    "elite_size",
    "alns_iterations",
    "alns_removal_q",
    "alns_seed",
    "alns_base_objective",
    "alns_best_objective",
    "alns_gain",
    "saa_sample_size",
    "saa_iterations",
    "saa_route_max_size",
    "saa_seed",
    "saa_log_every",
    "saa_route_pool_size",
    "saa_assembled_route_count",
]
benchmark_df[[c for c in detail_cols if c in benchmark_df.columns]]
# Out:
#            algorithm  \
# 0  real_gap_vrp_alns
# 1       real_gap_vrp
# 2   real_gap_vrp_saa
# 3          real_milp
# 4       real_genetic
#
#                                                                                                                                                         checks  \
# 0  {'hard_constraints_ok': True, 'daily_limits_ok': True, 'reachability_ok': True, 'all_tasks_assigned': True, 'mno_coverage_ok': True, 'all_checks_ok': True}
# 1  {'hard_constraints_ok': True, 'daily_limits_ok': True, 'reachability_ok': True, 'all_tasks_assigned': True, 'mno_coverage_ok': True, 'all_checks_ok': True}
# 2  {'hard_constraints_ok': True, 'daily_limits_ok': True, 'reachability_ok': True, 'all_tasks_assigned': True, 'mno_coverage_ok': True, 'all_checks_ok': True}
# 3  {'hard_constraints_ok': True, 'daily_limits_ok': True, 'reachability_ok': True, 'all_tasks_assigned': True, 'mno_coverage_ok': True, 'all_checks_ok': True}
# 4  {'hard_constraints_ok': True, 'daily_limits_ok': True, 'reachability_ok': True, 'all_tasks_assigned': True, 'mno_coverage_ok': True, 'all_checks_ok': True}
#
#   step1_method  gap_iter  used_agents  time_limit_sec  unassigned_penalty  \
# 0           lp      20.0         50.0             NaN                 NaN
# 1           lp      20.0         50.0             NaN                 NaN
# 2           lp      20.0         50.0             NaN                 NaN
# 3          NaN       NaN          NaN            90.0          10000000.0
# 4          NaN       NaN          NaN             NaN                 NaN
#
#    population_size  generations  generations_requested  ...  \
# 0              NaN          NaN                    NaN  ...
# 1              NaN          NaN                    NaN  ...
# 2              NaN          NaN                    NaN  ...
# 3              NaN          NaN                    NaN  ...
# 4             20.0         20.0                   20.0  ...
#
#    alns_base_objective  alns_best_objective  alns_gain  saa_sample_size  \
# 0              932.842              877.338     55.504              NaN
# 1                  NaN                  NaN        NaN              NaN
# 2                  NaN                  NaN        NaN             12.0
# 3                  NaN                  NaN        NaN              NaN
# 4                  NaN                  NaN        NaN              NaN
#
#    saa_iterations  saa_route_max_size  saa_seed  saa_log_every  \
# 0             NaN                 NaN       NaN            NaN
# 1             NaN                 NaN       NaN            NaN
# 2            60.0                 8.0      42.0           10.0
# 3             NaN                 NaN       NaN            NaN
# 4             NaN                 NaN       NaN            NaN
#
#    saa_route_pool_size  saa_assembled_route_count
# 0                  NaN                        NaN
# 1                  NaN                        NaN
# 2                120.0                       12.0
# 3                  NaN                        NaN
# 4                  NaN                        NaN
#
# [5 rows x 25 columns]

# %%
# Optional: agent/task breakdown tables
from flowopt.reporting import solution_breakdown_tables
from IPython.display import Markdown, display

MAX_AGENTS_TO_SHOW = 30
MAX_TASK_IDS_IN_CELL = 12
MAX_TASK_ROWS_TO_SHOW = 300

for _, row in benchmark_df.iterrows():
    algo = row.get("algorithm", "unknown")
    tables = solution_breakdown_tables(
        row,
        max_agents=MAX_AGENTS_TO_SHOW,
        max_task_ids=MAX_TASK_IDS_IN_CELL,
    )

    display(Markdown(f"### {algo}: решение по агентам"))
    display(tables["summary"])

    if tables["agents"].empty:
        print("No active agents in solution")
        continue

    display(tables["agents"])
    display(Markdown(f"**{algo}: задача -> агент (первые {MAX_TASK_ROWS_TO_SHOW} строк)**"))
    display(tables["tasks"].head(MAX_TASK_ROWS_TO_SHOW))
# Out:
# ### real_gap_vrp_alns: решение по агентам
#            algorithm  active_agents  assigned_tasks  total_mass_tons  \
# 0  real_gap_vrp_alns              5              32              0.0
#
#    total_km  total_hours
# 0   877.338       43.596
#       agent_id vehicle_type  is_compact  tasks_count  routes_count  \
# 0  AGENT_00252        VT_AB       False           11            11
# 1  AGENT_00254        VT_AB       False           10            10
# 2  AGENT_00124        VT_AB       False            6             6
# 3  AGENT_00316        VT_AB       False            4             4
# 4  AGENT_00516       VT_ABD       False            1             1
#
#    total_mass_tons  total_km  deadhead_km  deadhead_share_pct  total_hours  \
# 0                0   276.094      147.216              53.321       13.924
# 1                0   235.561      136.837              58.090       12.015
# 2                0   132.783       66.903              50.385        6.853
# 3                0   109.541       59.619              54.426        5.444
# 4                0   123.360       90.608              73.450        5.360
#
#                                                                                                        task_ids
# 0  LP_T0016, LP_T0009, LP_T0014, LP_T0010, LP_T0022, LP_T0007, LP_T0026, LP_T0027, LP_T0028, LP_T0029, LP_T0008
# 1            LP_T0002, LP_T0011, LP_T0024, LP_T0020, LP_T0013, LP_T0015, LP_T0012, LP_T0000, LP_T0021, LP_T0030
# 2                                                    LP_T0023, LP_T0019, LP_T0025, LP_T0001, LP_T0004, LP_T0003
# 3                                                                        LP_T0006, LP_T0005, LP_T0017, LP_T0018
# 4                                                                                                      LP_T0031
# **real_gap_vrp_alns: задача -> агент (первые 300 строк)**
#             algorithm     agent_id  task_order   task_id
# 0   real_gap_vrp_alns  AGENT_00252           1  LP_T0016
# 1   real_gap_vrp_alns  AGENT_00252           2  LP_T0009
# 2   real_gap_vrp_alns  AGENT_00252           3  LP_T0014
# 3   real_gap_vrp_alns  AGENT_00252           4  LP_T0010
# 4   real_gap_vrp_alns  AGENT_00252           5  LP_T0022
# 5   real_gap_vrp_alns  AGENT_00252           6  LP_T0007
# 6   real_gap_vrp_alns  AGENT_00252           7  LP_T0026
# 7   real_gap_vrp_alns  AGENT_00252           8  LP_T0027
# 8   real_gap_vrp_alns  AGENT_00252           9  LP_T0028
# 9   real_gap_vrp_alns  AGENT_00252          10  LP_T0029
# 10  real_gap_vrp_alns  AGENT_00252          11  LP_T0008
# 11  real_gap_vrp_alns  AGENT_00254           1  LP_T0002
# 12  real_gap_vrp_alns  AGENT_00254           2  LP_T0011
# 13  real_gap_vrp_alns  AGENT_00254           3  LP_T0024
# 14  real_gap_vrp_alns  AGENT_00254           4  LP_T0020
# 15  real_gap_vrp_alns  AGENT_00254           5  LP_T0013
# 16  real_gap_vrp_alns  AGENT_00254           6  LP_T0015
# 17  real_gap_vrp_alns  AGENT_00254           7  LP_T0012
# 18  real_gap_vrp_alns  AGENT_00254           8  LP_T0000
# 19  real_gap_vrp_alns  AGENT_00254           9  LP_T0021
# 20  real_gap_vrp_alns  AGENT_00254          10  LP_T0030
# 21  real_gap_vrp_alns  AGENT_00124           1  LP_T0023
# 22  real_gap_vrp_alns  AGENT_00124           2  LP_T0019
# 23  real_gap_vrp_alns  AGENT_00124           3  LP_T0025
# 24  real_gap_vrp_alns  AGENT_00124           4  LP_T0001
# 25  real_gap_vrp_alns  AGENT_00124           5  LP_T0004
# 26  real_gap_vrp_alns  AGENT_00124           6  LP_T0003
# 27  real_gap_vrp_alns  AGENT_00316           1  LP_T0006
# 28  real_gap_vrp_alns  AGENT_00316           2  LP_T0005
# 29  real_gap_vrp_alns  AGENT_00316           3  LP_T0017
# 30  real_gap_vrp_alns  AGENT_00316           4  LP_T0018
# 31  real_gap_vrp_alns  AGENT_00516           1  LP_T0031
# ### real_gap_vrp: решение по агентам
#       algorithm  active_agents  assigned_tasks  total_mass_tons  total_km  \
# 0  real_gap_vrp              6              32              0.0   932.842
#
#    total_hours
# 0       45.908
#       agent_id vehicle_type  is_compact  tasks_count  routes_count  \
# 0  AGENT_00254        VT_AB       False           10            10
# 1  AGENT_00316        VT_AB       False            7             7
# 2  AGENT_00124        VT_AB       False            6             6
# 3  AGENT_00252        VT_AB       False            5             5
# 4  AGENT_00251        VT_AB       False            3             3
# 5  AGENT_00516       VT_ABD       False            1             1
#
#    total_mass_tons  total_km  deadhead_km  deadhead_share_pct  total_hours  \
# 0                0   237.760      140.055              58.906       12.107
# 1                0   177.783       99.710              56.085        8.948
# 2                0   132.783       66.903              50.385        6.853
# 3                0   180.895      107.573              59.467        8.637
# 4                0    80.262       51.837              64.585        4.004
# 5                0   123.360       90.608              73.450        5.360
#
#                                                                                              task_ids
# 0  LP_T0002, LP_T0020, LP_T0010, LP_T0005, LP_T0015, LP_T0012, LP_T0013, LP_T0000, LP_T0021, LP_T0030
# 1                                LP_T0014, LP_T0009, LP_T0011, LP_T0018, LP_T0006, LP_T0007, LP_T0008
# 2                                          LP_T0023, LP_T0019, LP_T0025, LP_T0001, LP_T0004, LP_T0003
# 3                                                    LP_T0016, LP_T0026, LP_T0027, LP_T0028, LP_T0029
# 4                                                                        LP_T0022, LP_T0024, LP_T0017
# 5                                                                                            LP_T0031
# **real_gap_vrp: задача -> агент (первые 300 строк)**
#        algorithm     agent_id  task_order   task_id
# 0   real_gap_vrp  AGENT_00254           1  LP_T0002
# 1   real_gap_vrp  AGENT_00254           2  LP_T0020
# 2   real_gap_vrp  AGENT_00254           3  LP_T0010
# 3   real_gap_vrp  AGENT_00254           4  LP_T0005
# 4   real_gap_vrp  AGENT_00254           5  LP_T0015
# 5   real_gap_vrp  AGENT_00254           6  LP_T0012
# 6   real_gap_vrp  AGENT_00254           7  LP_T0013
# 7   real_gap_vrp  AGENT_00254           8  LP_T0000
# 8   real_gap_vrp  AGENT_00254           9  LP_T0021
# 9   real_gap_vrp  AGENT_00254          10  LP_T0030
# 10  real_gap_vrp  AGENT_00316           1  LP_T0014
# 11  real_gap_vrp  AGENT_00316           2  LP_T0009
# 12  real_gap_vrp  AGENT_00316           3  LP_T0011
# 13  real_gap_vrp  AGENT_00316           4  LP_T0018
# 14  real_gap_vrp  AGENT_00316           5  LP_T0006
# 15  real_gap_vrp  AGENT_00316           6  LP_T0007
# 16  real_gap_vrp  AGENT_00316           7  LP_T0008
# 17  real_gap_vrp  AGENT_00124           1  LP_T0023
# 18  real_gap_vrp  AGENT_00124           2  LP_T0019
# 19  real_gap_vrp  AGENT_00124           3  LP_T0025
# 20  real_gap_vrp  AGENT_00124           4  LP_T0001
# 21  real_gap_vrp  AGENT_00124           5  LP_T0004
# 22  real_gap_vrp  AGENT_00124           6  LP_T0003
# 23  real_gap_vrp  AGENT_00252           1  LP_T0016
# 24  real_gap_vrp  AGENT_00252           2  LP_T0026
# 25  real_gap_vrp  AGENT_00252           3  LP_T0027
# 26  real_gap_vrp  AGENT_00252           4  LP_T0028
# 27  real_gap_vrp  AGENT_00252           5  LP_T0029
# 28  real_gap_vrp  AGENT_00251           1  LP_T0022
# 29  real_gap_vrp  AGENT_00251           2  LP_T0024
# 30  real_gap_vrp  AGENT_00251           3  LP_T0017
# 31  real_gap_vrp  AGENT_00516           1  LP_T0031
# ### real_gap_vrp_saa: решение по агентам
#           algorithm  active_agents  assigned_tasks  total_mass_tons  total_km  \
# 0  real_gap_vrp_saa             12              32              0.0    1035.4
#
#    total_hours
# 0       47.719
#        agent_id vehicle_type  is_compact  tasks_count  routes_count  \
# 0   AGENT_00020         VT_A       False            8             8
# 1   AGENT_00249         VT_A       False            8             8
# 2   AGENT_00277        VT_AD       False            4             4
# 3   AGENT_00250        VT_AB       False            4             4
# 4   AGENT_00252        VT_AB       False            1             1
# 5   AGENT_00251        VT_AB       False            1             1
# 6   AGENT_00300         VT_A       False            1             1
# 7   AGENT_00255        VT_AB       False            1             1
# 8   AGENT_00254        VT_AB       False            1             1
# 9   AGENT_00030         VT_A       False            1             1
# 10  AGENT_00253        VT_AB       False            1             1
# 11  AGENT_00391         VT_A        True            1             1
#
#     total_mass_tons  total_km  deadhead_km  deadhead_share_pct  total_hours  \
# 0                 0   195.125      117.730              60.336        9.265
# 1                 0   258.483      149.944              58.009       11.702
# 2                 0   134.175       90.888              67.738        6.041
# 3                 0   136.339       84.694              62.120        6.561
# 4                 0    16.951       14.501              85.542        0.926
# 5                 0    20.047       10.302              51.388        1.055
# 6                 0    25.165       20.071              79.756        1.188
# 7                 0    26.836       19.813              73.832        1.338
# 8                 0    29.394       14.808              50.378        1.445
# 9                 0    32.007       21.488              67.136        1.451
# 10                0    37.518       24.397              65.027        1.783
# 11                0   123.360       90.608              73.450        4.965
#
#                                                                           task_ids
# 0   LP_T0001, LP_T0004, LP_T0013, LP_T0002, LP_T0024, LP_T0020, LP_T0014, LP_T0007
# 1   LP_T0005, LP_T0010, LP_T0015, LP_T0026, LP_T0030, LP_T0027, LP_T0028, LP_T0029
# 2                                           LP_T0009, LP_T0006, LP_T0018, LP_T0019
# 3                                           LP_T0000, LP_T0003, LP_T0023, LP_T0008
# 4                                                                         LP_T0016
# 5                                                                         LP_T0012
# 6                                                                         LP_T0011
# 7                                                                         LP_T0022
# 8                                                                         LP_T0021
# 9                                                                         LP_T0025
# 10                                                                        LP_T0017
# 11                                                                        LP_T0031
# **real_gap_vrp_saa: задача -> агент (первые 300 строк)**
#            algorithm     agent_id  task_order   task_id
# 0   real_gap_vrp_saa  AGENT_00020           1  LP_T0001
# 1   real_gap_vrp_saa  AGENT_00020           2  LP_T0004
# 2   real_gap_vrp_saa  AGENT_00020           3  LP_T0013
# 3   real_gap_vrp_saa  AGENT_00020           4  LP_T0002
# 4   real_gap_vrp_saa  AGENT_00020           5  LP_T0024
# 5   real_gap_vrp_saa  AGENT_00020           6  LP_T0020
# 6   real_gap_vrp_saa  AGENT_00020           7  LP_T0014
# 7   real_gap_vrp_saa  AGENT_00020           8  LP_T0007
# 8   real_gap_vrp_saa  AGENT_00249           1  LP_T0005
# 9   real_gap_vrp_saa  AGENT_00249           2  LP_T0010
# 10  real_gap_vrp_saa  AGENT_00249           3  LP_T0015
# 11  real_gap_vrp_saa  AGENT_00249           4  LP_T0026
# 12  real_gap_vrp_saa  AGENT_00249           5  LP_T0030
# 13  real_gap_vrp_saa  AGENT_00249           6  LP_T0027
# 14  real_gap_vrp_saa  AGENT_00249           7  LP_T0028
# 15  real_gap_vrp_saa  AGENT_00249           8  LP_T0029
# 16  real_gap_vrp_saa  AGENT_00277           1  LP_T0009
# 17  real_gap_vrp_saa  AGENT_00277           2  LP_T0006
# 18  real_gap_vrp_saa  AGENT_00277           3  LP_T0018
# 19  real_gap_vrp_saa  AGENT_00277           4  LP_T0019
# 20  real_gap_vrp_saa  AGENT_00250           1  LP_T0000
# 21  real_gap_vrp_saa  AGENT_00250           2  LP_T0003
# 22  real_gap_vrp_saa  AGENT_00250           3  LP_T0023
# 23  real_gap_vrp_saa  AGENT_00250           4  LP_T0008
# 24  real_gap_vrp_saa  AGENT_00252           1  LP_T0016
# 25  real_gap_vrp_saa  AGENT_00251           1  LP_T0012
# 26  real_gap_vrp_saa  AGENT_00300           1  LP_T0011
# 27  real_gap_vrp_saa  AGENT_00255           1  LP_T0022
# 28  real_gap_vrp_saa  AGENT_00254           1  LP_T0021
# 29  real_gap_vrp_saa  AGENT_00030           1  LP_T0025
# 30  real_gap_vrp_saa  AGENT_00253           1  LP_T0017
# 31  real_gap_vrp_saa  AGENT_00391           1  LP_T0031
# ### real_milp: решение по агентам
#    algorithm  active_agents  assigned_tasks  total_mass_tons  total_km  \
# 0  real_milp             23              32           37.617  4510.761
#
#    total_hours
# 0      190.646
#        agent_id vehicle_type  is_compact  tasks_count  routes_count  \
# 0   AGENT_00051        VT_AB       False            3             3
# 1   AGENT_00030         VT_A       False            2             2
# 2   AGENT_00611         VT_A       False            2             2
# 3   AGENT_00300         VT_A       False            2             2
# 4   AGENT_00081        VT_AB       False            2             2
# 5   AGENT_00275        VT_AB       False            2             2
# 6   AGENT_00254        VT_AB       False            2             2
# 7   AGENT_00255        VT_AB       False            2             2
# 8   AGENT_00333        VT_AB       False            1             1
# 9   AGENT_00342        VT_AB       False            1             1
# 10  AGENT_00020         VT_A       False            1             1
# 11  AGENT_00117        VT_AB       False            1             1
# 12  AGENT_00082        VT_AB       False            1             1
# 13  AGENT_00083        VT_AB       False            1             1
# 14  AGENT_00618        VT_AD       False            1             1
# 15  AGENT_00061        VT_AB       False            1             1
# 16  AGENT_00277        VT_AD       False            1             1
# 17  AGENT_00250        VT_AB       False            1             1
# 18  AGENT_00391         VT_A        True            1             1
# 19  AGENT_00252        VT_AB       False            1             1
# 20  AGENT_00443        VT_AB       False            1             1
# 21  AGENT_00467        VT_AB       False            1             1
# 22  AGENT_00251        VT_AB       False            1             1
#
#     total_mass_tons  total_km  deadhead_km  deadhead_share_pct  total_hours  \
# 0            11.686   277.943      134.896              48.534       12.241
# 1             1.304   196.868       60.152              30.555        8.012
# 2             1.889   267.166      133.790              50.077       10.716
# 3             1.206   270.965      141.291              52.144       10.862
# 4             1.380   290.541      145.583              50.108       12.546
# 5             1.933   308.896      154.514              50.021       13.311
# 6             2.024   313.164      157.546              50.308       13.489
# 7             1.247   318.950      161.516              50.640       13.730
# 8             3.452    41.332       25.991              62.882        1.942
# 9             1.151   128.647       67.503              52.471        5.580
# 10            1.068   131.161       65.787              50.157        5.265
# 11            0.937   131.366       66.650              50.736        5.694
# 12            1.068   133.777       67.095              50.154        5.794
# 13            0.580   151.402       76.058              50.236        6.528
# 14            0.966   151.785       76.249              50.235        6.058
# 15            0.836   153.340       79.703              51.978        6.609
# 16            0.827   158.714       79.391              50.022        6.324
# 17            0.376   163.622       83.166              50.828        7.038
# 18            0.928   178.143       93.725              52.612        7.072
# 19            0.844   182.578       93.127              51.007        7.827
# 20            0.758   184.274       96.790              52.525        7.898
# 21            0.724   185.450       97.378              52.509        7.947
# 22            0.433   190.674       99.461              52.163        8.165
#
#                               task_ids
# 0   TASK_04481, TASK_18897, TASK_24673
# 1               TASK_04529, TASK_25152
# 2               TASK_02958, TASK_03016
# 3               TASK_07218, TASK_19026
# 4               TASK_01210, TASK_23276
# 5               TASK_13159, TASK_10706
# 6               TASK_12548, TASK_24166
# 7               TASK_09403, TASK_13014
# 8                           TASK_25035
# 9                           TASK_19520
# 10                          TASK_02580
# 11                          TASK_02641
# 12                          TASK_02354
# 13                          TASK_28664
# 14                          TASK_17808
# 15                          TASK_15511
# 16                          TASK_08880
# 17                          TASK_08647
# 18                          TASK_08108
# 19                          TASK_07846
# 20                          TASK_11997
# 21                          TASK_18137
# 22                          TASK_07922
# **real_milp: задача -> агент (первые 300 строк)**
#     algorithm     agent_id  task_order     task_id
# 0   real_milp  AGENT_00051           1  TASK_04481
# 1   real_milp  AGENT_00051           2  TASK_18897
# 2   real_milp  AGENT_00051           3  TASK_24673
# 3   real_milp  AGENT_00030           1  TASK_04529
# 4   real_milp  AGENT_00030           2  TASK_25152
# 5   real_milp  AGENT_00611           1  TASK_02958
# 6   real_milp  AGENT_00611           2  TASK_03016
# 7   real_milp  AGENT_00300           1  TASK_07218
# 8   real_milp  AGENT_00300           2  TASK_19026
# 9   real_milp  AGENT_00081           1  TASK_01210
# 10  real_milp  AGENT_00081           2  TASK_23276
# 11  real_milp  AGENT_00275           1  TASK_13159
# 12  real_milp  AGENT_00275           2  TASK_10706
# 13  real_milp  AGENT_00254           1  TASK_12548
# 14  real_milp  AGENT_00254           2  TASK_24166
# 15  real_milp  AGENT_00255           1  TASK_09403
# 16  real_milp  AGENT_00255           2  TASK_13014
# 17  real_milp  AGENT_00333           1  TASK_25035
# 18  real_milp  AGENT_00342           1  TASK_19520
# 19  real_milp  AGENT_00020           1  TASK_02580
# 20  real_milp  AGENT_00117           1  TASK_02641
# 21  real_milp  AGENT_00082           1  TASK_02354
# 22  real_milp  AGENT_00083           1  TASK_28664
# 23  real_milp  AGENT_00618           1  TASK_17808
# 24  real_milp  AGENT_00061           1  TASK_15511
# 25  real_milp  AGENT_00277           1  TASK_08880
# 26  real_milp  AGENT_00250           1  TASK_08647
# 27  real_milp  AGENT_00391           1  TASK_08108
# 28  real_milp  AGENT_00252           1  TASK_07846
# 29  real_milp  AGENT_00443           1  TASK_11997
# 30  real_milp  AGENT_00467           1  TASK_18137
# 31  real_milp  AGENT_00251           1  TASK_07922
# ### real_genetic: решение по агентам
#       algorithm  active_agents  assigned_tasks  total_mass_tons  total_km  \
# 0  real_genetic             32              32           37.617  4627.014
#
#    total_hours
# 0      195.709
#        agent_id vehicle_type  is_compact  tasks_count  routes_count  \
# 0   AGENT_00083        VT_AB       False            1             1
# 1   AGENT_00344        VT_AB       False            1             1
# 2   AGENT_00617        VT_AD       False            1             1
# 3   AGENT_00020         VT_A       False            1             1
# 4   AGENT_00333        VT_AB       False            1             1
# 5   AGENT_00061        VT_AB       False            1             1
# 6   AGENT_00620        VT_AD       False            1             1
# 7   AGENT_00316        VT_AB       False            1             1
# 8   AGENT_00124        VT_AB       False            1             1
# 9   AGENT_00085        VT_AB       False            1             1
# 10  AGENT_00117        VT_AB       False            1             1
# 11  AGENT_00611         VT_A       False            1             1
# 12  AGENT_00081        VT_AB       False            1             1
# 13  AGENT_00300         VT_A       False            1             1
# 14  AGENT_00118        VT_AB       False            1             1
# 15  AGENT_00619        VT_AD       False            1             1
# 16  AGENT_00082        VT_AB       False            1             1
# 17  AGENT_00051        VT_AB       False            1             1
# 18  AGENT_00080        VT_AB       False            1             1
# 19  AGENT_00618        VT_AD       False            1             1
# 20  AGENT_00254        VT_AB       False            1             1
# 21  AGENT_00277        VT_AD       False            1             1
# 22  AGENT_00249         VT_A       False            1             1
# 23  AGENT_00252        VT_AB       False            1             1
# 24  AGENT_00250        VT_AB       False            1             1
# 25  AGENT_00255        VT_AB       False            1             1
# 26  AGENT_00251        VT_AB       False            1             1
# 27  AGENT_00538       VT_ABD       False            1             1
# 28  AGENT_00275        VT_AB       False            1             1
# 29  AGENT_00516       VT_ABD       False            1             1
#
#     total_mass_tons  total_km  deadhead_km  deadhead_share_pct  total_hours  \
# 0             9.779    32.007       21.488              67.136        1.554
# 1             3.452    41.332       25.991              62.882        1.942
# 2             1.088   123.787       62.886              50.802        4.981
# 3             1.063   127.622       65.117              51.024        5.129
# 4             1.151   128.647       67.503              52.471        5.580
# 5             1.068   131.161       65.787              50.157        5.685
# 6             0.937   131.366       66.650              50.736        5.273
# 7             0.815   131.915       71.766              54.403        5.716
# 8             1.068   133.777       67.095              50.154        5.794
# 9             0.933   134.221       67.317              50.154        5.813
# 10            0.956   134.569       68.097              50.603        5.827
# 11            0.844   140.460       70.437              50.147        5.622
# 12            0.828   141.787       71.206              50.221        6.128
# 13            0.391   144.583       75.058              51.913        5.781
# 14            0.552   149.370       74.993              50.206        6.444
# 15            0.580   151.402       76.058              50.236        6.043
# 16            0.966   151.785       76.249              50.235        6.544
# 17            0.836   153.340       79.703              51.978        6.609
# 18            0.216   154.545       78.730              50.943        6.659
# 19            0.403   155.080       79.832              51.478        6.185
# 20            1.074   155.574       77.853              50.042        6.702
# 21            1.012   155.582       78.754              50.619        6.204
# 22            0.859   156.731       80.069              51.087        6.248
# 23            1.012   158.493       79.702              50.287        6.824
# 24            0.827   158.714       79.391              50.022        6.833
# 25            0.376   163.622       83.166              50.828        7.038
# 26            0.844   164.422       82.235              50.014        7.071
# 27            0.928   178.143       93.725              52.612        7.643
# 28            0.844   182.578       93.127              51.007        7.827
# 29            0.758   184.274       96.790              52.525        7.898
#
#       task_ids
# 0   TASK_18897
# 1   TASK_25035
# 2   TASK_04529
# 3   TASK_04481
# 4   TASK_19520
# 5   TASK_02580
# 6   TASK_02641
# 7   TASK_07218
# 8   TASK_02354
# 9   TASK_02958
# 10  TASK_03016
# 11  TASK_24673
# 12  TASK_01210
# 13  TASK_19026
# 14  TASK_23276
# 15  TASK_28664
# 16  TASK_17808
# 17  TASK_15511
# 18  TASK_25152
# 19  TASK_09403
# 20  TASK_13159
# 21  TASK_12548
# 22  TASK_10706
# 23  TASK_24166
# 24  TASK_08880
# 25  TASK_08647
# 26  TASK_13014
# 27  TASK_08108
# 28  TASK_07846
# 29  TASK_11997
# **real_genetic: задача -> агент (первые 300 строк)**
#        algorithm     agent_id  task_order     task_id
# 0   real_genetic  AGENT_00083           1  TASK_18897
# 1   real_genetic  AGENT_00344           1  TASK_25035
# 2   real_genetic  AGENT_00617           1  TASK_04529
# 3   real_genetic  AGENT_00020           1  TASK_04481
# 4   real_genetic  AGENT_00333           1  TASK_19520
# 5   real_genetic  AGENT_00061           1  TASK_02580
# 6   real_genetic  AGENT_00620           1  TASK_02641
# 7   real_genetic  AGENT_00316           1  TASK_07218
# 8   real_genetic  AGENT_00124           1  TASK_02354
# 9   real_genetic  AGENT_00085           1  TASK_02958
# 10  real_genetic  AGENT_00117           1  TASK_03016
# 11  real_genetic  AGENT_00611           1  TASK_24673
# 12  real_genetic  AGENT_00081           1  TASK_01210
# 13  real_genetic  AGENT_00300           1  TASK_19026
# 14  real_genetic  AGENT_00118           1  TASK_23276
# 15  real_genetic  AGENT_00619           1  TASK_28664
# 16  real_genetic  AGENT_00082           1  TASK_17808
# 17  real_genetic  AGENT_00051           1  TASK_15511
# 18  real_genetic  AGENT_00080           1  TASK_25152
# 19  real_genetic  AGENT_00618           1  TASK_09403
# 20  real_genetic  AGENT_00254           1  TASK_13159
# 21  real_genetic  AGENT_00277           1  TASK_12548
# 22  real_genetic  AGENT_00249           1  TASK_10706
# 23  real_genetic  AGENT_00252           1  TASK_24166
# 24  real_genetic  AGENT_00250           1  TASK_08880
# 25  real_genetic  AGENT_00255           1  TASK_08647
# 26  real_genetic  AGENT_00251           1  TASK_13014
# 27  real_genetic  AGENT_00538           1  TASK_08108
# 28  real_genetic  AGENT_00275           1  TASK_07846
# 29  real_genetic  AGENT_00516           1  TASK_11997
# 30  real_genetic  AGENT_00471           1  TASK_18137
# 31  real_genetic  AGENT_00253           1  TASK_07922
